# %% [markdown]
# # **ENGG680 - Introduction to Digital Engineering**
# ## *Lab Assignment 1: Using Git and Python for Collaborative Coding in Google Colab*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Preliminary: Certificate of Work

# %% [markdown]
# *We, the undersigned, certify that this is our own work, which has been done expressly for this course, either without the assistance of any other party or where appropriate we have acknowledged the work of others. Further, we have read and understood the section in the university calendar on plagiarism/cheating/other academic misconduct and we are aware of the implications thereof. We request that the total mark for this assignment be distributed as follows among group members:*

# %% [markdown]
# |          | First Name | Last Name | Signature (Full Name, Date) | Hours | Contribution % |
# |----------|------------|-----------|-----------------------------|-------|----------------|
# | Member 1: | Ashish     | Naik      | AshishNaik Oct162024| 5     | 25% |
# | Member 2: | Rica Marie | Opo | RicaMarieOpo Oct182024| 4 | 25% |
# | Member 3: | Roya | Molaei | RoyaMolaei oct172024 | 4 | 25% |
# | Member 4: | Ioana | Rontu | IoanaRontu Oct172024 | 4 | 25% |

# %% [markdown]
# # **Linear LSE**
# ### (40 Marks)

# %% [markdown]
# ### **Curve Fitting**

# %% [markdown]
# ![Screenshot from 2024-09-27 11-33-51.png](data:image/png;base64,...)

# %% [markdown]
# ### **Observations:** values of a function f(a) in range of -π to π, contaminated with random noise

# %% [markdown]
# ### **Unknown States:** coefficients of polynomial functions for curve fitting

# %%
# step 1
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# step 2
# Load data.xlsx file, which contains the observations (with noise), variance of observations and true observations
# hint: use pandas library to parse excel file and use numpy library to convert it to array
# (1 mark)
df_data = pd.read_excel('/content/drive/My Drive/engg680_2024_fall/Lab_Assignment2/data.xlsx')
arr_data = np.asarray(df_data)

#store the noisy observations, variance of observations and true observations into numpy arrays seperately
# (1 mark)
l = arr_data[ :,0]
l_var = arr_data[ :,1]
l_true = arr_data[ :,2]

# %%
# step 3
# define the number of observation n
# (1 mark)
n = len(arr_data)

# define the observation weight matrix P for LSE as identity matrix
# identity weight matrix simply means the observations will be unweighted in the following LSE
# (1 mark)
P = np.eye(n)

# define the range of function input(i.e., constants a), from start to end; and the numerical array of a
start = -1* np.pi
end = np.pi
a = np.linspace(start, end, n)

# %%
# step 4
# use the matplotlib to plot the true and noisy observations together in one single figure
# use scatter for noisy observation plotting
# for the true observation, label it as "f(a)"" and set color as 'k'
# for the noisy observation scatter plot, label it as "f(a) + e", set color as 'tab:blue', set marker as 'o' and set alpha as 0.3
# include proper axis labels, legend and title
# scale the range of x-axis to be -1 to 1
# keep this format for the rest of the plots in this lab assignment
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

ax.scatter(a, l, label='f(a) + e', color='tab:blue', marker='o', alpha=0.3)
ax.plot(a, l_true, label='f(a)', color='k')

ax.set_xlabel('input a')
ax.set_ylabel('Observations')
ax.set_xlim(-1, 1)
ax.legend()
ax.set_title('True Observations and Noisy Observations')

ax.grid(True, which='both',ls='-',color='0.65')
fig.tight_layout()
plt.show()

# %%
# step 5
# define a curve fitting function named fit_polynomial_curve
# the function should implement the linear least square estimation
# the function should include all important intermediate steps in LSE
# the input and output of the funciton are described in the comment below in red.
# please keep code clean and well-commented
# (9 marks)

"""
def fit_polynomial_curve(a: np.ndarray, l: np.ndarray, P: np.ndarray, deg: int) -> tuple:
    '''
    Args:
        a:              function input (constants)
        l:              noisy observations
        P:              observation weight matrix
        deg:            degree of polynomial to fit to data
    Returns:
        x:              estimated polynomial coefficients
        cov_x:          uncertainty in estimated coefficients
        apv:            a posterier variance factor (goodness of fit)
        v:              observation residuals
    '''
    return (x, cov_x, apv, v)
deg=0
A = np.vstack([a**i for i in range(deg + 1)]).T

# Weighted least squares estimation
A_T_P_A = A.T @ P @ A
A_T_P_l = A.T @ P @ l

x = np.linalg.solve(A_T_P_A, A_T_P_l)
v = l - A @ x  #residual
cov_x = np.linalg.inv(A_T_P_A) * np.var(v)
apv = np.var(v)
"""
def fit_polynomial_curve(a: np.ndarray, l: np.ndarray, P: np.ndarray, deg: int) -> tuple:
    '''
    Args:
        a:              function input (constants)
        l:              noisy observations
        P:              observation weight matrix
        deg:            degree of polynomial to fit to data
    Returns:
        x:              estimated polynomial coefficients
        cov_x:          uncertainty in estimated coefficients
        apv:            a posterier variance factor (goodness of fit)
        v:              observation residuals
    '''
    # Matrix A
    A = np.vstack([a**i for i in range(deg + 1)]).T

    # Weighted least squares estimation
    A_T_P_A = A.T @ P @ A
    A_T_P_l = A.T @ P @ l

    # Calculating the coefficient
    x = np.linalg.solve(A_T_P_A, A_T_P_l)

    # Residual calculation
    v = l - A @ x

    # Calcualting the covariance
    cov_x = np.linalg.inv(A_T_P_A) * np.var(v)

    # Calculating posterier variance factor
    apv = np.var(v)

    return (x, cov_x, apv, v)

# %%
# step 6
# call the fit_polynomial_curve function and fetch the results
# use polynomial degrees of: 1, 3 ,5
# (1 marks)
"""
for degree in [1, 3, 5]:
    x, cov_x, apv, residuals = fit_polynomial_curve(a, l, P, degree)
    print(f"Degree: {degree}")
    print("Estimated polynomial coefficient:", x)
    print("Uncertainty in estimated coefficients:", cov_x)
    print("Posterior variance factor (goodness of fit):", apv)
    print("Observation Residuals:", residuals)
    print()

    """

results = {}
for degree in [1, 3, 5]:
    x, cov_x, apv, residuals = fit_polynomial_curve(a, l, P, degree)

    #storing the results for future steps
    results[degree] = {
        'coefficients': x,
        'covariance': cov_x,
        'posterior_variance': apv,
        'residuals': residuals
    }

    print(f"Degree: {degree}")
    print("Estimated polynomial coefficient:", x)
    print("Uncertainty in estimated coefficients:", cov_x)
    print("Posterior variance factor (goodness of fit):", apv)
    print("Observation Residuals:", residuals)
    print()
# Out:
# Degree: 1
# Estimated polynomial coefficient: [-16.59352348   7.25633807]
# Uncertainty in estimated coefficients: [[3.24183276e-01 3.34739049e-17]
#  [3.34739049e-17 9.81465270e-02]]
# Posterior variance factor (goodness of fit): 162.0916381699047
# Observation Residuals: [ 2.31950929e+01  2.33624696e+01  5.16650752e-01  2.33475847e+01
#   1.96698387e+01  2.37681600e+01  2.33453696e+01  2.18331528e+01
#   2.11355408e+01  5.61358715e+00  2.24756392e+01  1.33407067e+01
#   2.34014210e+01  2.24034178e+01  1.13532794e+01  2.53650032e+01
#   1.44202357e+01  8.52085442e+00  1.79247562e+01  2.11851700e+00
#   1.46072683e+01  9.70673172e+00  1.30817824e+01  1.63166651e+01
#   1.15688083e+01  1.16383392e+01  6.07754648e+00  3.24693889e+01
#   1.42879391e+01  1.41679638e+01  1.73166729e+01  7.83535648e+00
#   1.73215977e+01  1.35522578e+01 -5.87401633e+00 -2.04342770e+00
#   8.45600371e+00 -7.17469845e+00  7.13670400e+00  4.93927812e+00
#   7.53688443e+00  1.29373203e+01  6.55314295e+00  5.69877998e+00
#   1.01514943e+01  4.53954123e+00  1.48752086e+01  9.72183415e+00
#   5.32287382e+00  5.37717018e+00  3.28635164e+01  1.05508888e+01
#   2.78273101e+01  9.16488366e+00  5.14599136e-02  3.19863498e-01
#  -1.97363242e+01  6.81034218e+00  4.72890560e+00 -2.10226861e+00
#  -2.79584973e+00  2.32455093e+00 -1.14423918e+01 -1.24887757e+01
#   7.38138618e+00  1.03552389e+00 -1.18704801e+00 -2.46038448e+01
#   1.07362212e+01 -7.63712467e+00  1.96792954e+00  2.26894634e+00
#  -9.57220285e+00 -5.42926366e+00  1.61074346e+01 -3.34833084e+00
#  -6.94840126e+00 -3.44558186e+00 -8.00889546e+00 -3.39309833e+00
#  -4.74295332e+00  4.14673594e+00 -6.40404185e+00 -1.65906289e+01
#  -6.71907146e+00 -6.97540785e+00 -6.55915076e+00 -9.33009632e-01
#  -2.75215517e+00 -2.85164695e+00 -1.47812505e+01 -4.93518081e+00
#  -2.72396787e+00 -1.06647537e+01 -8.74184363e+00 -2.16949094e+01
#  -1.54271795e+00 -9.16043805e+00 -2.06104298e-01 -7.22080635e+00
#  -1.12313175e+01 -1.51886455e+01 -2.59718109e+01 -3.25021425e+01
#  -1.66457389e+01 -3.83182678e-01 -1.09450044e+01 -2.82344144e+01
#  -3.22948710e+00 -6.63510649e-01 -6.39204581e+00 -6.36581983e+00
#  -1.14771813e+01 -2.50374549e+01 -1.80692120e+01 -1.41118278e+01
#  -1.46285050e+01 -1.16514080e+01 -7.99118639e+00 -1.60773244e+01
#   3.62913759e-01 -1.62422976e+01 -9.66671730e+00 -1.06336228e+01
#  -1.28103560e+01 -1.18230933e+01 -1.56420753e+01 -1.08469860e+01
#  -1.00116207e+01 -1.24508540e+01 -1.76116600e+01 -1.58786639e+01
#  -9.09983105e+00 -9.85187390e+00 -2.80628344e+01 -2.72754987e+00
#  -2.95803453e+01 -2.56222853e+00 -8.77234085e+00 -1.08426717e+01
#  -1.44868704e+01 -1.12858613e+01  9.48894769e-01 -1.07017131e+01
#  -2.24782500e+01 -1.12429899e+01 -1.19993641e+01  2.24924459e+00
#  -1.33591949e+01 -1.14442635e+01 -8.62467760e+00 -1.39741109e+01
#   6.44549860e+00 -2.59318022e+01 -4.23955008e+00 -9.76527596e+00
#  -1.26056311e+01  1.74775385e+01 -1.48672920e+01 -1.71572214e+01
#  -1.16689054e+01 -1.22039427e+01 -5.23524204e+00 -1.24191944e+01
#  -1.15745060e+01  8.11562081e+00 -1.77596017e+01 -1.41301965e+01
#  -3.05376704e+00 -1.47270639e+01 -1.65003001e+01 -6.87653187e+00
#   9.84596111e-01 -1.30051805e+01 -1.37428693e+01 -1.47379014e+01
#  -1.59134941e+01 -1.14546703e+00 -1.17322493e+01 -1.42193372e+01
#  -8.30081606e+00 -5.27555401e-02 -1.20793685e+01 -3.00168097e+01
#   1.93590708e+01 -1.94771245e+01 -1.57640621e+01 -9.59220337e+00
#  -1.11430252e+01 -1.15776900e+01 -3.13533077e+00 -1.76874647e+01
#  -1.67223952e+01 -1.01283523e+01 -1.41741274e+01 -9.61220441e+00
#  -6.67946256e+00 -3.08897039e+01 -5.77123964e+00 -1.19429543e+01
#  -2.05605750e+01 -8.12228732e+00 -8.58849203e+00 -7.67145800e+00
#  -7.35778372e+00  3.01693496e+00 -1.31001464e+01 -7.68500234e+00
#  -1.47822603e+01 -6.95652296e+00 -8.22816081e+00 -9.80916061e+00
#  -8.48097787e+00 -2.11918849e+00 -1.03196463e+01 -9.63372660e+00
#  -6.80283609e+00 -1.60179773e+01 -5.99860293e+00 -6.44058859e+00
#  -1.44819007e+01 -1.89587060e+01 -2.14425272e+01 -2.26075190e+01
#  -5.16340537e+00 -3.27702596e+00 -2.54337331e+00 -1.17812622e+01
#  -4.66601234e+00 -1.22667187e+00 -1.56278482e+01 -3.53222505e+00
#  -5.52306626e-01 -1.05138968e+01  5.04716553e+00 -8.86683618e+00
#  -1.16644855e+01  4.92626359e+00  9.52518530e+00 -1.45487211e+00
#   2.16118158e+00 -3.61294706e+00 -1.05813418e+01  3.02270579e-01
#   3.04609159e+00 -4.16113524e+00  5.21058666e+00 -4.82642992e+00
#  -9.72466910e+00  9.04019223e+00  1.35421603e+01 -3.91520523e+00
#   2.07152027e+01 -2.29693475e+00  1.58707072e+00  3.43944809e-01
#   5.07004588e+00  4.06271161e+00  2.30569101e+00 -5.68903254e-01
#  -1.52194607e+01  1.44253846e+01 -2.85245412e+00  2.00575702e+00
#   3.75186666e+00  5.89577528e+00  2.99149187e+00 -1.32101354e+00
#  -4.52222355e-01  3.17843416e+00  1.77294617e+00  4.01085115e+00
#   3.39482327e+00  1.07193228e+01  3.66951769e+00 -8.94908569e+00
#   1.80727401e+01  1.44551820e+01  2.58907541e+01 -8.64143201e+00
#   3.64961122e+00  1.50422942e+01  1.06032419e+01  7.48399976e+00
#  -1.58746972e+01 -2.27022330e+00  9.49600196e+00  1.51049796e+01
#   6.47408974e+00  1.66910483e+01 -3.11194918e+00  3.30869071e+00
#  -1.37874905e+00  6.74638693e+00  9.91930851e+00  5.31713938e+00
#   2.82128831e+01  1.05045329e+01  2.13654353e+01  1.29054158e+01
#   2.44241674e+01  9.67207609e-01  1.03644845e+01  9.33553325e+00
#   1.52338157e+01  3.56074805e+00  1.12540095e+01  1.08821183e+01
#   5.36469144e+00  1.16999869e+01  2.07179656e+01  9.36149213e+00
#   1.11338758e+01  1.26443131e+00  3.78157751e+01  2.06993326e+01
#   1.40536182e+01  1.87692560e+01  1.47090684e+01  1.96208363e+01
#   9.76338501e+00 -2.43415304e-01  1.38529709e+01  1.04973388e+01
#   1.02325343e+01  1.26851960e+01  9.81340476e+00  2.59483692e+01
#   6.89629483e+00  1.07546680e+01  1.29099379e+01  1.46182895e+01
#   4.49032459e+00  1.32197286e+01  1.49441950e+01  9.15785880e+00
#   1.74562381e+01  1.04161087e+01  1.07849607e+01  1.43671023e+01
#   1.28764707e+01  2.90073158e+01  1.52486246e+01  2.56052962e+01
#  -6.46811993e+00  1.05878909e+01  3.66036257e+00  6.24691482e+00
#   2.62548508e-01  1.41946307e+01  1.46100860e+01  1.36233966e+01
#   8.96230795e+00  1.19942212e+01  5.55182322e+00  1.69612045e+01
#   8.77709755e+00  1.00938666e+01  1.44414734e+01  3.54713526e+00
#   1.49035600e+01  2.16630462e+01  1.35591872e+01  1.92057031e+01
#   1.57342373e+00  9.31031278e+00  1.25647019e+01 -8.73634816e-01
#   1.46022529e+01  2.32840892e+01 -1.28836028e+01  7.71330510e-01
#   1.28701499e+01  1.59108535e+01  2.00749870e+01  1.22346371e+01
#   1.14913281e+01  1.27372049e+01  7.09690394e+00  5.85147911e+00
#   8.25057588e+00  1.10939965e+01  5.11157566e+00  5.53127678e+00
#   1.05290433e+01  1.15802072e+01  9.12909554e+00  4.51137407e+00
#   9.57407237e+00  2.66203885e+00  1.32377599e+01  6.99416842e+00
#   3.53496638e-02  8.16712799e+00  1.12246236e+01  1.54577849e+01
#   9.01062531e+00  1.54895123e+00  1.28692815e+01  9.88152367e-01
#   1.51144217e+01  3.55443849e+00  1.56450727e+01  1.75327615e+01
#   1.20672315e+01  1.57533638e+01  5.29943076e+00  2.36923864e+00
#   6.61902314e+00  4.15382813e+00  1.79736885e+01 -2.52021035e+00
#   1.22109754e+01  9.62563108e+00  7.96033014e+00  1.63492684e+01
#   4.87181801e+00 -2.31227680e+00  7.29615536e+00  2.81816910e+00
#   6.32299873e+00  1.28095248e+01  1.08078307e+00  1.09096225e+01
#   1.51789993e+00  7.78695615e+00  3.60551434e+00  5.52724872e+00
#   9.96434076e-01 -4.43408709e+00 -1.48844834e+00  9.77477635e+00
#  -7.64639153e-01 -8.81493444e+00 -1.23509833e+00  1.87730234e-01
#  -1.32534187e+01 -8.11940116e+00 -4.78145300e+00 -1.61164515e+01
#  -8.28570495e+00 -7.68131549e+00 -1.47211318e+01  1.20818687e+00
#   9.88753153e+00  7.70620952e+00  1.52158101e+00  2.63134421e+00
#   7.56447568e+00 -3.64990369e+00  1.85956387e+00  7.85805010e+00
#  -5.70665774e+00  8.58149728e+00 -1.32857951e+01 -1.04132145e+01
#  -5.86027839e+00 -5.66206783e+00 -1.61625803e+01 -3.63280535e+00
#  -8.10306871e+00 -1.44537500e+01 -8.58061957e+00 -9.58698678e+00
#  -8.12794398e+00 -2.17038648e+01  3.30798032e+00 -4.51634584e+00
#   1.61390455e+00 -1.10025641e+01 -1.16776002e+01 -1.61675131e+01
#  -5.57029462e+00 -1.24242370e+01 -1.47183728e+01 -5.51741351e+00
#  -1.88496003e+00 -1.40541503e+01 -1.30811858e+01 -1.87396276e+01
#   1.44621764e-01 -2.71756717e+01 -2.59344168e+01 -1.65777871e+01
#  -1.30560370e+01 -1.12065692e+01 -1.82767086e+01 -1.40063718e+01
#  -2.40895688e+01 -2.80326783e+01 -2.81671466e+01 -8.88914045e+00
#  -1.33375428e+01 -2.05494360e+01 -1.79181990e+01 -2.85945607e+00
#  -2.35918356e+01 -2.90113840e+01 -1.41244068e+01 -2.28392568e+01]
#
# Degree: 3
# Estimated polynomial coefficient: [-16.72496774  19.63961372   0.03979476  -2.08281013]
# Uncertainty in estimated coefficients: [[ 2.95216456e-01  1.24308333e-16 -4.96540530e-02 -1.69308093e-17]
#  [ 1.24308333e-16  2.48274237e-01 -2.16570798e-17 -3.50774003e-02]
#  [-4.96540530e-02 -2.16570798e-17  1.50327707e-02  3.12837228e-18]
#  [-1.69308093e-17 -3.50774003e-02  3.12837228e-18  5.89985773e-03]]
# Posterior variance factor (goodness of fit): 65.60321960866828
# Observation Residuals: [-2.74320068e+00 -1.95519951e+00 -2.41866060e+01 -7.47447072e-01
#  -3.82313043e+00  8.71116077e-01  1.03813848e+00  1.09647003e-01
#  -1.03022642e-02 -1.49606308e+01  2.46703376e+00 -6.10827396e+00
#   4.50610228e+00  4.05582337e+00 -6.45250372e+00  8.09514350e+00
#  -2.31956359e+00 -7.69472240e+00  2.22758878e+00 -1.30660292e+01
#  -7.04198312e-02 -4.46983659e+00 -5.99379308e-01  3.12522158e+00
#  -1.13858039e+00 -5.90633079e-01 -5.67862284e+00  2.11804339e+01
#   3.46063498e+00  3.79677188e+00  7.39607939e+00 -1.64012728e+00
#   8.28575988e+00  4.95062702e+00 -1.40468539e+01 -9.79286103e+00
#   1.12461061e+00 -1.40933904e+01  6.25399130e-01 -1.16992885e+00
#   1.82451115e+00  7.61654147e+00  1.61874422e+00  1.14557200e+00
#   5.97431266e+00  7.33246440e-01  1.14346862e+01  6.64199447e+00
#   2.59865228e+00  3.00352710e+00  3.08354371e+01  8.86338345e+00
#   2.64754138e+01  8.14365662e+00 -6.44012827e-01 -5.47449319e-02
#  -1.97949334e+01  7.06289220e+00  5.28779966e+00 -1.24182072e+00
#  -1.63861324e+00  3.77383571e+00 -9.70577407e+00 -1.04695154e+01
#   9.67862352e+00  3.60609781e+00  1.65224693e+00 -2.15004194e+01
#   1.40992113e+01 -4.01911053e+00  5.83645195e+00  6.38348620e+00
#  -5.21611141e+00 -8.36061555e-01  2.09333314e+01  1.70586961e+00
#  -1.67026322e+00  2.05215264e+00 -2.29588068e+00  2.53090550e+00
#   1.38777327e+00  1.04799440e+01  1.27431213e-01 -9.86508224e+00
#   1.96382315e-01  1.25811491e-01  7.23717559e-01  6.52741601e+00
#   4.88176110e+00  4.95171820e+00 -6.81245324e+00  3.19505665e+00
#   5.56374290e+00 -2.22351153e+00 -1.50987146e-01 -1.29583306e+01
#   7.33571600e+00 -1.43991080e-01  8.94453846e+00  2.06023994e+00
#  -1.82363503e+00 -5.65806915e+00 -1.63220581e+01 -2.27369059e+01
#  -6.76868576e+00  9.60204425e+00 -8.55221302e-01 -1.80436677e+01
#   7.05865533e+00  9.71848477e+00  4.08028477e+00  4.19335302e+00
#  -8.34634083e-01 -1.43149764e+01 -7.27022020e+00 -3.23971587e+00
#  -3.68664097e+00 -6.43135092e-01  3.08017706e+00 -4.94616367e+00
#   1.15506034e+01 -5.00132240e+00  1.62432493e+00  7.04292993e-01
#  -1.42873523e+00 -4.00911211e-01 -4.18245049e+00  6.46987845e-01
#   1.51363327e+00 -8.97363584e-01 -6.03295214e+00 -4.27773238e+00
#   2.52035505e+00  1.78462278e+00 -1.64129463e+01  8.93283566e+00
#  -1.79123316e+01  9.11056911e+00  2.90242145e+00  8.31260944e-01
#  -2.81653686e+00  3.78128648e-01  1.26038217e+01  9.41456283e-01
#  -1.08495078e+01  3.68680536e-01 -4.07385243e-01  1.38189372e+01
#  -1.81435838e+00  7.31720282e-02  2.86283707e+00 -2.51901202e+00
#   1.78657116e+01 -1.45489201e+01  7.10358100e+00  1.53570892e+00
#  -1.34916262e+00  2.86871453e+01 -3.70686724e+00 -6.04827408e+00
#  -6.13705874e-01 -1.20473649e+00  5.70575036e+00 -1.53861138e+00
#  -7.56503115e-01  1.88688980e+01 -7.07317097e+00 -3.51270803e+00
#   7.49270826e+00 -4.25364766e+00 -6.10196378e+00  3.44472849e+00
#   1.12268095e+01 -2.84396024e+00 -3.66456337e+00 -4.74440591e+00
#  -6.00668040e+00  8.67281866e+00 -2.00431304e+00 -4.58354673e+00
#   1.24105712e+00  9.39345383e+00 -2.73054449e+00 -2.07670676e+01
#   2.85080591e+01 -1.04305366e+01 -6.82149635e+00 -7.55256583e-01
#  -2.41326932e+00 -2.95667188e+00  5.37542754e+00 -9.28846322e+00
#  -8.43662264e+00 -1.95725584e+00 -6.11912915e+00 -1.67470164e+00
#   1.13917244e+00 -2.31912841e+01  1.80564269e+00 -4.48890698e+00
#  -1.32306351e+01 -9.17702469e-01 -1.51048482e+00 -7.21226081e-01
#  -5.36499808e-01  9.70812311e+00 -6.54017682e+00 -1.25734922e+00
#  -8.48799649e+00 -7.96696520e-01 -2.20379472e+00 -3.92125294e+00
#  -2.73050174e+00  3.49290792e+00 -4.84685288e+00 -4.30113436e+00
#  -1.61131841e+00 -1.09683825e+01 -1.09175456e+00 -1.67728508e+00
#  -9.86291563e+00 -1.44847879e+01 -1.71143997e+01 -1.84258808e+01
#  -1.12893028e+00  6.09637268e-01  1.19485420e+00 -8.19206930e+00
#  -1.22642801e+00  2.06275488e+00 -1.24891031e+01 -5.44660670e-01
#   2.28360286e+00 -7.83009143e+00  7.57844253e+00 -6.48848688e+00
#  -9.43943822e+00  6.99765937e+00  1.14426051e+01  3.08272247e-01
#   3.76977589e+00 -2.15915242e+00 -9.28257146e+00  1.44581679e+00
#   4.03423894e+00 -3.32853659e+00  5.88751173e+00 -4.30527837e+00
#  -9.35936605e+00  9.24959673e+00  1.35956411e+01 -4.01764816e+00
#   2.04568608e+01 -2.71112589e+00  1.01710505e+00 -3.81695744e-01
#   4.18885504e+00  3.02612003e+00  1.11387318e+00 -1.91574789e+00
#  -1.67211077e+01  1.27691845e+01 -4.66293305e+00  4.12985215e-02
#   1.63375278e+00  3.62435515e+00  5.67139567e-01 -3.89789899e+00
#  -3.18121698e+00  2.97779285e-01 -1.25889508e+00  8.28322338e-01
#   6.21306696e-02  7.23701511e+00  3.81685987e-02 -1.27288776e+01
#   1.41451290e+01  1.03804002e+01  2.16694749e+01 -1.30085100e+01
#  -8.62542322e-01  1.03858135e+01  5.80320713e+00  2.54120926e+00
#  -2.09594203e+01 -7.49603096e+00  4.12998281e+00  9.59964697e+00
#   8.30366517e-01  1.09098824e+01 -9.02958493e+00 -2.74441710e+00
#  -7.56630619e+00  4.25428142e-01  3.46602070e+00 -1.26737988e+00
#   2.14982550e+01  3.66094329e+00  1.43940566e+01  5.80744548e+00
#   1.72008277e+01 -6.38025416e+00  2.89417283e+00  1.74366889e+00
#   7.52172075e+00 -4.27023045e+00  3.30551950e+00  2.81751364e+00
#  -2.81460587e+00  3.40744375e+00  1.23136484e+01  8.46897661e-01
#   2.51052569e+00 -7.46612770e+00  2.89795787e+01  1.17590954e+01
#   5.01096167e+00  9.62582658e+00  5.46653745e+00  1.02809002e+01
#   3.27764962e-01 -9.77297302e+00  4.23124665e+00  7.85244213e-01
#   4.31890428e-01  2.79784886e+00 -1.58774732e-01  1.58932533e+01
#  -3.23983659e+00  5.39466815e-01  2.61763782e+00  4.25088613e+00
#  -5.95016133e+00  2.70820566e+00  4.36370565e+00 -1.48950146e+00
#   6.74412739e+00 -3.58607107e-01 -5.01898120e-02  3.47371229e+00
#   1.92706155e+00  1.80041326e+01  4.19393764e+00  1.45014004e+01
#  -1.76189044e+01 -6.07437347e-01 -7.57713950e+00 -5.03036618e+00
#  -1.10520916e+01  2.84507626e+00  3.22808699e+00  2.21144766e+00
#  -2.47707132e+00  5.29956226e-01 -5.93475801e+00  5.45490150e+00
#  -2.74630776e+00 -1.44399668e+00  2.89182146e+00 -8.01161110e+00
#   3.33843845e+00  1.00942936e+01  1.98957269e+00  7.63802068e+00
#  -9.98950759e+00 -2.24502348e+00  1.01982964e+00 -1.24051493e+01
#   3.08701501e+00  1.17880716e+01 -2.43574314e+01 -1.06773154e+01
#   1.44970530e+00  4.52165360e+00  8.72010038e+00  9.17157149e-01
#   2.14373249e-01  1.50391842e+00 -4.08954583e+00 -5.28494078e+00
#  -2.83259594e+00  6.73158383e-02 -5.85534573e+00 -5.37259234e+00
#  -3.08455603e-01  8.12421427e-01 -1.56560921e+00 -6.10685687e+00
#  -9.64267009e-01 -7.79296626e+00  2.86955673e+00 -3.28374024e+00
#  -1.01487469e+01 -1.91961403e+00  1.23880362e+00  5.57647929e+00
#  -7.62548541e-01 -8.11244858e+00  3.32332302e+00 -8.43867270e+00
#   5.81044726e+00 -5.62294330e+00  6.59805065e+00  8.61989116e+00
#   3.29232976e+00  7.12027252e+00 -3.18798319e+00 -5.96860623e+00
#  -1.56533591e+00 -3.87310345e+00  1.01081510e+01 -1.02203622e+01
#   4.68022576e+00  2.26832506e+00  7.80534154e-01  9.35107385e+00
#  -1.94065888e+00 -8.93489472e+00  8.67562591e-01 -3.41220736e+00
#   2.95054680e-01  6.98825421e+00 -4.52954809e+00  5.51452169e+00
#  -3.65765455e+00  2.83528878e+00 -1.11790011e+00  1.03647791e+00
#  -3.25727741e+00 -8.44629862e+00 -5.25469433e+00  6.25898642e+00
#  -4.02545754e+00 -1.18162409e+01 -3.97232741e+00 -2.28083119e+00
#  -1.54486971e+01 -1.00367565e+01 -6.41622003e+00 -1.74639401e+01
#  -9.34120008e+00 -8.44007712e+00 -1.51783950e+01  1.05721206e+00
#   1.00476599e+01  8.18228094e+00  2.31846020e+00  3.75392087e+00
#   9.01766446e+00 -1.86116321e+00  3.98882061e+00  1.03328126e+01
#  -2.88137507e+00  1.17623395e+01 -9.74432896e+00 -6.50603514e+00
#  -1.58227162e+00 -1.00809445e+00 -1.11274762e+01  1.78861859e+00
#  -2.29011094e+00 -8.24401938e+00 -1.96885225e+00 -2.56789385e+00
#  -6.96211630e-01 -1.38541543e+01  1.15810328e+01  4.18543717e+00
#   1.07498317e+01 -1.42705417e+00 -1.65704405e+00 -5.69642227e+00
#   5.35684434e+00 -1.03551154e+00 -2.86249765e+00  6.81119966e+00
#   1.09220043e+01 -7.63196587e-01  6.99420310e-01 -4.46368092e+00
#   1.49216219e+01 -1.18918802e+01 -1.01380710e+01 -2.63099178e-01
#   3.78280582e+00  6.16226624e+00 -3.72017870e-01  4.44006187e+00
#  -5.09547965e+00 -8.48499611e+00 -8.05990890e+00  1.17836402e+01
#   7.90679314e+00  1.27249255e+00  4.48738444e+00  2.01358695e+01
#  -6.55820742e-04 -4.81821293e+00  1.06769178e+01  2.57640811e+00]
#
# Degree: 5
# Estimated polynomial coefficient: [-1.65770980e+01  2.28207004e+01 -1.09433276e-01 -3.58096979e+00
#   1.75697706e-02  1.36073672e-01]
# Uncertainty in estimated coefficients: [[ 4.42929519e-01  9.74213095e-16 -2.08601400e-01 -3.53569086e-16
#    1.89466846e-02  2.81994321e-17]
#  [ 9.74213095e-16  7.30122425e-01 -6.73316060e-16 -2.65264196e-01
#    7.18288110e-17  2.10339780e-02]
#  [-2.08601400e-01 -6.73316060e-16  1.76835723e-01  2.44427171e-16
#   -1.91207273e-02 -1.94677455e-17]
#  [-3.53569086e-16 -2.65264196e-01  2.44427171e-16  1.14730789e-01
#   -2.60710201e-17 -9.90612971e-03]
#  [ 1.89466846e-02  7.18288110e-17 -1.91207273e-02 -2.60710201e-17
#    2.25123101e-03  2.07831665e-18]
#  [ 2.81994321e-17  2.10339780e-02 -1.94677455e-17 -9.90612971e-03
#    2.07831665e-18  8.99746192e-04]]
# Posterior variance factor (goodness of fit): 62.99324449462198
# Observation Residuals: [ 2.05284391e+00  2.54476017e+00 -1.99742521e+01  3.18564203e+00
#  -1.61102442e-01  4.27015086e+00  4.18211339e+00  3.00636208e+00
#   2.64682091e+00 -1.25355624e+01  4.66745490e+00 -4.12522091e+00
#   6.27893928e+00  5.62547044e+00 -5.07914517e+00  9.27899149e+00
#  -1.31857049e+00 -6.87004960e+00  2.88235600e+00 -1.25748715e+01
#   2.63306822e-01 -4.28747875e+00 -5.62443215e-01  3.02256902e+00
#  -1.37510133e+00 -9.55413770e-01 -6.16616514e+00  2.05755188e+01
#   2.74362763e+00  2.97284583e+00  6.47030225e+00 -2.66279271e+00
#   7.17106529e+00  3.74865986e+00 -1.53314385e+01 -1.11555083e+01
#  -3.11643696e-01 -1.55988943e+01 -9.45094021e-01 -2.80124678e+00
#   1.36438031e-01  5.87568895e+00 -1.71004640e-01 -6.89281772e-01
#   4.09805479e+00 -1.18080422e+00  9.48636551e+00  4.66283921e+00
#   5.92011376e-01  9.72664181e-01  2.87835314e+01  6.79353108e+00
#   2.43906284e+01  6.04687063e+00 -2.74994722e+00 -2.16705480e+00
#  -2.19109241e+01  4.94583817e+00  3.17222342e+00 -3.35345330e+00
#  -3.74391060e+00  1.67719181e+00 -1.17915186e+01 -1.25421862e+01
#   7.62113064e+00  1.56581734e+00 -3.68855121e-01 -2.35004446e+01
#   1.21220947e+01 -5.97155249e+00  3.91038587e+00  4.48543337e+00
#  -7.08457658e+00 -2.67342670e+00  1.91285175e+01 -6.50020550e-02
#  -3.40586101e+00  3.53101929e-01 -3.95716869e+00  9.08539149e-01
#  -1.94568285e-01  8.93867541e+00 -1.37177020e+00 -1.13212756e+01
#  -1.21591439e+00 -1.24175152e+00 -5.98325343e-01  5.25162980e+00
#   3.65291917e+00  3.77046000e+00 -7.94553562e+00  2.11069569e+00
#   4.52860325e+00 -3.20897487e+00 -1.08636327e+00 -1.38432519e+01
#   6.50157467e+00 -9.27069041e-01  8.21276636e+00  1.37997602e+00
#  -2.45222779e+00 -6.23486641e+00 -1.68469734e+01 -2.32098897e+01
#  -7.18972511e+00  9.23292688e+00 -1.17247407e+00 -1.83091474e+01
#   6.84482394e+00  9.55614411e+00  3.96924537e+00  4.13339420e+00
#  -8.43763516e-01 -1.42735575e+01 -7.17856296e+00 -3.09815886e+00
#  -3.49555044e+00 -4.02904310e-01  3.36912846e+00 -4.60893696e+00
#   1.19356351e+01 -4.56898041e+00  2.10345885e+00  1.22967743e+00
#  -8.57664067e-01  2.15261134e-01 -3.52178362e+00  1.35152212e+00
#   2.26138797e+00 -1.07054653e-01 -5.20077379e+00 -3.40438742e+00
#   3.43414644e+00  2.73812361e+00 -1.54204892e+01  9.96348027e+00
#  -1.68442832e+01  1.02152230e+01  4.04286876e+00  2.00667635e+00
#  -1.60699142e+00  1.62095389e+00  1.38790650e+01  2.24824460e+00
#  -9.51205780e+00  1.73589890e+00  9.88698675e-01  1.52429750e+01
#  -3.63286809e-01  1.55034945e+00  4.36518507e+00 -9.92435565e-01
#   1.94155681e+01 -1.29767379e+01  8.69712929e+00  3.14965883e+00
#   2.84220049e-01  3.03389880e+01 -2.03754070e+00 -4.36244279e+00
#   1.08764854e+00  5.11157413e-01  7.43519853e+00  2.03404695e-01
#   9.97093824e-01  2.06330885e+01 -5.29937406e+00 -1.73029123e+00
#   9.28275944e+00 -2.45694617e+00 -4.29959420e+00  5.25178619e+00
#   1.30375780e+01 -1.03045520e+00 -1.84929262e+00 -2.92833645e+00
#  -4.19077504e+00  1.04876017e+01 -1.91605577e-01 -2.77386281e+00
#   3.04677519e+00  1.11942698e+01 -9.35560530e-01 -1.89788389e+01
#   3.02886166e+01 -8.65855915e+00 -5.05900002e+00  9.96865693e-01
#  -6.72405732e-01 -1.22794294e+00  7.09115485e+00 -7.58659526e+00
#  -6.74946215e+00 -2.85641088e-01 -4.46388826e+00 -3.66522780e-02
#   2.75922329e+00 -2.15900277e+01  3.38731981e+00 -2.92758234e+00
#  -1.16904244e+01  6.00644842e-01 -1.47380976e-02  7.51195348e-01
#   9.11884370e-01  1.11317710e+01 -5.14195096e+00  1.14782186e-01
#  -7.14261833e+00  5.21283448e-01 -9.13843858e-01 -2.65994786e+00
#  -1.49844470e+00  4.69512928e+00 -3.67504003e+00 -3.16028789e+00
#  -5.01981015e-01 -9.89108161e+00 -4.70020381e-02 -6.65577226e-01
#  -8.88473293e+00 -1.35405949e+01 -1.62046449e+01 -1.75509964e+01
#  -2.89332210e-01  1.41354956e+00  1.96269788e+00 -7.46066036e+00
#  -5.31803120e-01  2.72026334e+00 -1.18690264e+01  3.76859740e-02
#   2.82793846e+00 -7.32403058e+00  8.04598227e+00 -6.05969713e+00
#  -9.04960984e+00  7.34833261e+00  1.17539471e+01  5.80124491e-01
#   4.00199773e+00 -1.96668388e+00 -9.12996129e+00  1.55848139e+00
#   4.10688866e+00 -3.29595314e+00  5.87999545e+00 -4.35290990e+00
#  -9.44711040e+00  9.12175996e+00  1.34277503e+01 -4.22553679e+00
#   2.02090486e+01 -2.99876952e+00  6.89740015e-01 -7.48654308e-01
#   3.78244866e+00  2.58042933e+00  6.29079412e-01 -2.43944579e+00
#  -1.72834932e+01  1.21683456e+01 -5.30197365e+00 -6.35674688e-01
#   9.19133446e-01  2.87239346e+00 -2.21843489e-01 -4.72356533e+00
#  -4.04321147e+00 -6.00171346e-01 -2.19241301e+00 -1.40357350e-01
#  -9.41288658e-01  6.19929472e+00 -1.03339794e+00 -1.38338192e+01
#   1.30072995e+01  9.21018600e+00  2.04673949e+01 -1.42419214e+01
#  -2.12673515e+00  9.09140449e+00  4.47916240e+00  1.18812412e+00
#  -2.23409357e+01 -8.90535191e+00  2.69349547e+00  8.13664658e+00
#  -6.58479538e-01  9.39587182e+00 -1.05680652e+01 -4.30665892e+00
#  -9.15158823e+00 -1.18215985e+00  1.83687373e+00 -2.91732636e+00
#   1.98282807e+01  1.97172485e+00  1.26863895e+01  4.08213650e+00
#   1.54586950e+01 -8.13838148e+00  1.12089065e+00 -4.39179964e-02
#   5.72068944e+00 -6.08383606e+00  1.48021926e+00  9.81407688e-01
#  -4.66061967e+00  1.55242859e+00  1.04505467e+01 -1.02336776e+00
#   6.34027067e-01 -9.34792168e+00  2.70934343e+01  9.86955202e+00
#   3.11897732e+00  7.73236511e+00  3.57256839e+00  8.38739832e+00
#  -1.56428999e+00 -1.16625968e+01  2.34504242e+00 -1.09654826e+00
#  -1.44449469e+00  9.27869707e-01 -2.02134670e+00  1.40390920e+01
#  -5.08458209e+00 -1.29485621e+00  7.94744895e-01  2.44043148e+00
#  -7.74716942e+00  9.25652149e-01  2.59661398e+00 -3.24012521e+00
#   5.01097602e+00 -2.07328373e+00 -1.74539184e+00  1.79898170e+00
#   2.73795764e-01  1.63733211e+01  2.58656534e+00  1.29184474e+01
#  -1.91764633e+01 -2.13863332e+00 -9.08101012e+00 -6.50595590e+00
#  -1.24984523e+01  1.42888491e+00  1.84299677e+00  8.58381414e-01
#  -3.79720022e+00 -7.56331977e-01 -7.18631274e+00  4.23896193e+00
#  -3.92576216e+00 -2.58610811e+00  1.78789803e+00 -9.07651485e+00
#   2.31337216e+00  9.10986803e+00  1.04657608e+00  6.73722556e+00
#  -1.08473449e+01 -3.05916356e+00  2.50108801e-01 -1.31297470e+01
#   2.40822583e+00  1.11557569e+01 -2.49426256e+01 -1.12147635e+01
#   9.60607564e-01  4.08148884e+00  8.32942868e+00  5.76515502e-01
#  -7.57251119e-02  1.26485216e+00 -4.27711626e+00 -5.42057739e+00
#  -2.91588718e+00  3.67544177e-02 -5.83282067e+00 -5.29665263e+00
#  -1.78802233e-01  9.96057576e-01 -1.32775174e+00 -5.81457084e+00
#  -6.17377173e-01 -7.39133012e+00  3.32604822e+00 -2.77231853e+00
#  -9.58235508e+00 -1.29824777e+00  1.91511213e+00  6.30766073e+00
#   2.33985996e-02 -7.27188167e+00  4.21832430e+00 -7.48946265e+00
#   6.81359945e+00 -4.56615738e+00  7.70811932e+00  9.78284822e+00
#   4.50773667e+00  8.38764580e+00 -1.86917285e+00 -4.59893469e+00
#  -1.45426493e-01 -2.40362768e+00  1.16264725e+01 -8.65396547e+00
#   6.29387641e+00  3.92835679e+00  2.48602168e+00  1.11010386e+01
#  -1.47249737e-01 -7.09912893e+00  2.74454135e+00 -1.49521607e+00
#   2.25080039e+00  8.98143769e+00 -2.50030290e+00  7.57839218e+00
#  -1.56065639e+00  4.96385483e+00  1.04061101e+00  3.22324731e+00
#  -1.04400142e+00 -6.20833353e+00 -2.99392441e+00  8.54060923e+00
#  -1.72500242e+00 -9.49904358e+00 -1.64054869e+00  6.32967889e-02
#  -1.30945246e+01 -7.67491742e+00 -4.04916691e+00 -1.50942008e+01
#  -6.97137888e+00 -6.07285560e+00 -1.28165331e+01  3.41087501e+00
#   1.23902043e+01  1.05107057e+01  4.62968186e+00  6.04477266e+00
#   1.12848951e+01  3.79109588e-01  6.19871232e+00  1.25088124e+01
#  -7.42866414e-01  1.38596680e+01 -7.69196040e+00 -4.50249793e+00
#   3.68469954e-01  8.85793304e-01 -9.29459540e+00  3.55624314e+00
#  -5.92088981e-01 -6.62004463e+00 -4.23468671e-01 -1.10574586e+00
#   6.77954821e-01 -1.25728180e+01  1.27645864e+01  5.26615092e+00
#   1.17225422e+01 -5.67617570e-01 -9.16260171e-01 -5.07977944e+00
#   5.84374719e+00 -6.84059390e-01 -2.65231983e+00  6.87416543e+00
#   1.08317051e+01 -1.01293035e+00  2.83965009e-01 -5.05126362e+00
#   1.41553859e+01 -1.28434165e+01 -1.12816770e+01 -1.60566807e+00
#   2.23425621e+00  4.40059199e+00 -2.35408792e+00  2.23019636e+00
#  -7.54066999e+00 -1.11731716e+01 -1.09988621e+01  8.58598334e+00
#   4.44237191e+00 -2.46688969e+00  4.64707344e-01  1.58214251e+01
#  -4.61547948e+00 -9.74216911e+00  5.43493355e+00 -2.99264324e+00]

# %%
# step 7
# use the estimated coefficients x and constants array a, construct polynomial functions for each degree
# hint: use polyval function from numpy library (check input argument carefully)
# (1 marks)

line_uw = np.polyval(results[1]['coefficients'], a)
cubic_uw = np.polyval(results[3]['coefficients'], a)
quintic_uw = np.polyval(results[5]['coefficients'], a)

# %%
# step 8
# use the matplotlib to plot each polynomial function, noisy observations l, true observations l_true, together in one single figure
# for the polynomials of line, cubic and quintic, use color of orange, green and red respectively.
# (2 marks)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

# noisy observation, blue from step 4 above
ax.scatter(a, l, label='Noisy Observations (l)', color='tab:blue', marker='o', alpha=0.5)

# true observation, k color from step 4 above
ax.plot(a, l_true, label='True Observations (l_true)', color='k', linewidth=2)

# polynomial plotting
ax.plot(a, line_uw, label='Line Fit (Degree 1)', color='orange')
ax.plot(a, cubic_uw, label='Cubic Fit (Degree 3)', color='green')
ax.plot(a, quintic_uw, label='Quintic Fit (Degree 5)', color='red')

# configuring the chart
ax.set_xlabel('input a')
ax.set_ylabel('Observations')
ax.set_xlim(-4, 4)
ax.set_ylim(-200,200)
ax.legend()
ax.set_title('Polynomial Functions, Noisy Observations and True Observations')

ax.grid(True, which='both',ls='-',color='0.65')

fig.tight_layout()

plt.show()

# %%
# step 9
# print the a posterier variance factor for each polynomial function
# (3 marks)
for degree in [1, 3, 5]:
    apv = results[degree]['posterior_variance']

    print(f'The posterior variance factor for degree {degree}: {apv}')
# Out:
# The posterior variance factor for degree 1: 162.0916381699047
# The posterior variance factor for degree 3: 65.60321960866828
# The posterior variance factor for degree 5: 62.99324449462198

# %%
# step 10
# compute and print the norm between the predicted observations (output from each polynomial function) and the true observations
# (3 marks)
for degree in [1, 3, 5]:
  coefficients = results[degree]['coefficients']
  predicted = np.polyval(coefficients[::-1], a)

  norm = np.linalg.norm(predicted - l_true)

  print(f'The norm between the predicted observation and true observation for each degree {degree}: {norm}')
# Out:
# The norm between the predicted observation and true observation for each degree 1: 229.0601679674409
# The norm between the predicted observation and true observation for each degree 3: 38.28597992911666
# The norm between the predicted observation and true observation for each degree 5: 17.36996719696636

# %%
# step 11
# comment on the results of a posterier variance factor and norm, what pattern do you observe
# (2 marks)

# In both cases, as the degree of the polynomial increases, the values of the posterior variance factor and
# the norm decreases.

# %%
# step 12
# now, let's define the P matrix with the proper weights of observation
# use the variance of observation l_var, define P matrix
# (1 mark)
import numpy as np
P = np.diag(1/l_var)

# %%
# step 13
# repeat the steps 6-10, using the proper P matrix
# (10 marks)
weighted_results = {}

for degree in [1, 3, 5]:
    # Call the polynomial fitting function with the weighted P matrix
    x_weighted, cov_x_weighted, apv_weighted, residuals_weighted = fit_polynomial_curve(a, l, P, degree)

    # Storing the weighted results for future steps
    weighted_results[degree] = {
        'coefficients': x_weighted,
        'covariance': cov_x_weighted,
        'posterior_variance': apv_weighted,
        'residuals': residuals_weighted
    }

    # Print the results for weighted LSE
    print(f"Degree (Weighted): {degree}")
    print("Estimated polynomial coefficient:", x_weighted)
    print("Uncertainty in estimated coefficients:", cov_x_weighted)
    print("Posterior variance factor (goodness of fit):", apv_weighted)
    print("Observation Residuals:", residuals_weighted)
    print()

# Create the polynomial functions from the weighted results
line_weighted = np.polyval(weighted_results[1]['coefficients'], a)
cubic_weighted = np.polyval(weighted_results[3]['coefficients'], a)
quintic_weighted = np.polyval(weighted_results[5]['coefficients'], a)

# Plotting the graph for the weighted case
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(14, 5))

# Noisy observation, in blue from step 4 above
ax.scatter(a, l, label='Noisy Observations (l)', color='tab:blue', marker='o', alpha=0.5)

# True observation, k color from step 4 above
ax.plot(a, l_true, label='True Observations (l_true)', color='k', linewidth=2)

# Polynomial plotting with weighted results
ax.plot(a, line_weighted, label='Line Fit (Degree 1) - Weighted', color='orange')
ax.plot(a, cubic_weighted, label='Cubic Fit (Degree 3) - Weighted', color='green')
ax.plot(a, quintic_weighted, label='Quintic Fit (Degree 5) - Weighted', color='red')

# Configuring the chart
ax.set_xlabel('input a')
ax.set_ylabel('Observations')
ax.set_xlim(-4, 4)
ax.set_ylim(-200, 200)
ax.legend()
ax.grid(True, which='both', ls='-', color='0.65')

plt.title('Polynomial Functions (Weighted), Noisy Observations and True Observations')
plt.tight_layout()
plt.show()
# Out:
# Degree (Weighted): 1
# Estimated polynomial coefficient: [-16.54496159   7.67854617]
# Uncertainty in estimated coefficients: [[3.22773669 0.01267498]
#  [0.01267498 1.07560008]]
# Posterior variance factor (goodness of fit): 162.68043950201857
# Observation Residuals: [ 2.44729369e+01  2.46349973e+01  1.78386220e+00  2.46094799e+01
#   2.09264177e+01  2.50194227e+01  2.45913160e+01  2.30737830e+01
#   2.23708547e+01  6.84358480e+00  2.37003206e+01  1.45600719e+01
#   2.46154698e+01  2.36121505e+01  1.25566958e+01  2.65631033e+01
#   1.56130195e+01  9.70832203e+00  1.91069076e+01  3.29535209e+00
#   1.57787872e+01  1.08729343e+01  1.42426688e+01  1.74722352e+01
#   1.27190621e+01  1.27832767e+01  7.21716778e+00  3.36036939e+01
#   1.54169279e+01  1.52916364e+01  1.84350292e+01  8.94839650e+00
#   1.84293215e+01  1.46546653e+01 -4.77692507e+00 -9.51652696e-01
#   9.54246246e+00 -6.09355597e+00  8.21253024e+00  6.00978810e+00
#   8.60207815e+00  1.39971978e+01  7.60770415e+00  6.74802493e+00
#   1.11954230e+01  5.57815367e+00  1.59085048e+01  1.07498141e+01
#   6.34553749e+00  6.39451759e+00  3.38755476e+01  1.15576038e+01
#   2.88287087e+01  1.01609661e+01  1.04222605e+00  1.30531338e+00
#  -1.87561906e+01  7.78515955e+00  5.69840672e+00 -1.13808376e+00
#  -1.83698113e+00  3.27810327e+00 -1.04941557e+01 -1.15458558e+01
#   8.31898976e+00  1.96781121e+00 -2.60076946e-01 -2.36821899e+01
#   1.16525598e+01 -6.72610237e+00  2.87363558e+00  3.16933613e+00
#  -8.67712932e+00 -4.53950638e+00  1.69918756e+01 -2.46920608e+00
#  -6.07459276e+00 -2.57708961e+00 -7.14571947e+00 -2.53523859e+00
#  -3.89040984e+00  4.99396316e+00 -5.56213088e+00 -1.57540342e+01
#  -5.88779300e+00 -6.14944565e+00 -5.73850481e+00 -1.17679940e-01
#  -1.94214174e+00 -2.04694977e+00 -1.39818696e+01 -4.14111614e+00
#  -1.93521946e+00 -9.88132150e+00 -7.96372773e+00 -2.09221097e+01
#  -7.75234560e-01 -8.39827091e+00  5.50746579e-01 -6.46927173e+00
#  -1.04850992e+01 -1.44477434e+01 -2.52362250e+01 -3.17718730e+01
#  -1.59207855e+01  3.36454408e-01 -1.02306836e+01 -2.75254098e+01
#  -2.52579878e+00  3.48614128e-02 -5.69899000e+00 -5.67808028e+00
#  -1.07947580e+01 -2.43603479e+01 -1.73974212e+01 -1.34453533e+01
#  -1.39673467e+01 -1.09955659e+01 -7.34066063e+00 -1.54321149e+01
#   1.00280701e+00 -1.56077206e+01 -9.03745656e+00 -1.00096783e+01
#  -1.21917278e+01 -1.12097814e+01 -1.50340796e+01 -1.02443065e+01
#  -9.41425754e+00 -1.18588070e+01 -1.70249294e+01 -1.52972494e+01
#  -8.52373287e+00 -9.28109198e+00 -2.74973688e+01 -2.16740046e+00
#  -2.90255121e+01 -2.01271164e+00 -8.22814021e+00 -1.03037873e+01
#  -1.39533022e+01 -1.07576095e+01  1.47183039e+00 -1.01840937e+01
#  -2.19659469e+01 -1.07360030e+01 -1.14976935e+01  2.74559893e+00
#  -1.28681568e+01 -1.09585417e+01 -8.14427203e+00 -1.34990216e+01
#   6.91527165e+00 -2.54673454e+01 -3.78040953e+00 -9.31145167e+00
#  -1.21571230e+01  1.79207303e+01 -1.44294165e+01 -1.67246622e+01
#  -1.12416624e+01 -1.17820160e+01 -4.81863154e+00 -1.20079001e+01
#  -1.11685281e+01  8.51628254e+00 -1.73642562e+01 -1.37401672e+01
#  -2.66905408e+00 -1.43476672e+01 -1.61262196e+01 -6.50776767e+00
#   1.34804405e+00 -1.26470488e+01 -1.33900539e+01 -1.43904022e+01
#  -1.55713112e+01 -8.08600371e-01 -1.14006989e+01 -1.38931030e+01
#  -7.97989817e+00  2.62846096e-01 -1.17690831e+01 -2.97118405e+01
#   1.96587236e+01 -1.91827879e+01 -1.54750418e+01 -9.30849927e+00
#  -1.08646374e+01 -1.13046184e+01 -2.86757543e+00 -1.74250256e+01
#  -1.64652724e+01 -9.87654578e+00 -1.39276371e+01 -9.37103036e+00
#  -6.44360476e+00 -3.06591624e+01 -5.54601436e+00 -1.17230453e+01
#  -2.03459822e+01 -7.91301080e+00 -8.38453177e+00 -7.47281399e+00
#  -7.16445597e+00  3.20494645e+00 -1.29174512e+01 -7.50762336e+00
#  -1.46101975e+01 -6.78977649e+00 -8.06673060e+00 -9.65304665e+00
#  -8.33018016e+00 -1.97370705e+00 -1.01794812e+01 -9.49887767e+00
#  -6.67330341e+00 -1.58937608e+01 -5.87970276e+00 -6.32700468e+00
#  -1.43736331e+01 -1.88557546e+01 -2.13448920e+01 -2.25152001e+01
#  -5.07640274e+00 -3.19533959e+00 -2.46700319e+00 -1.17102083e+01
#  -4.60027473e+00 -1.16625052e+00 -1.55727431e+01 -3.48243621e+00
#  -5.07834042e-01 -1.04747405e+01  5.08100560e+00 -8.83831237e+00
#  -1.16412779e+01  4.94415490e+00  9.53776035e+00 -1.44761332e+00
#   2.16312412e+00 -3.61632078e+00 -1.05900317e+01  2.88264347e-01
#   3.02676910e+00 -4.18577399e+00  5.18063166e+00 -4.86170118e+00
#  -9.76525661e+00  8.99428846e+00  1.34909402e+01 -3.97174151e+00
#   2.06533502e+01 -2.36410354e+00  1.51458568e+00  2.66143507e-01
#   4.98692832e+00  3.97427779e+00  2.21194094e+00 -6.67969580e-01
#  -1.53238433e+01  1.43156858e+01 -2.96746921e+00  1.88542567e+00
#   3.62621906e+00  5.76481142e+00  2.85521175e+00 -1.46260992e+00
#  -5.99134984e-01  3.02620527e+00  1.61540103e+00  3.84798975e+00
#   3.22664562e+00  1.05458289e+01  3.49070753e+00 -9.13321211e+00
#   1.78832974e+01  1.42604231e+01  2.56906789e+01 -8.84682345e+00
#   3.43890352e+00  1.48262703e+01  1.03819017e+01  7.25734329e+00
#  -1.61066699e+01 -2.50751228e+00  9.25339673e+00  1.48570581e+01
#   6.22085199e+00  1.64324943e+01 -3.37581944e+00  3.03950420e+00
#  -1.65325182e+00  6.46656790e+00  9.63417323e+00  5.02668784e+00
#   2.79171153e+01  1.02034489e+01  2.10590350e+01  1.25936993e+01
#   2.41071345e+01  6.44858534e-01  1.00368191e+01  9.00255166e+00
#   1.48955179e+01  3.21713395e+00  1.09050792e+01  1.05278717e+01
#   5.00512857e+00  1.13351078e+01  2.03477702e+01  8.98598050e+00
#   1.07530479e+01  8.78287169e-01  3.74243147e+01  2.03025559e+01
#   1.36515253e+01  1.83618468e+01  1.42963430e+01  1.92027946e+01
#   9.34002707e+00 -6.72089497e-01  1.34189804e+01  1.00580321e+01
#   9.78791137e+00  1.22352568e+01  9.35814929e+00  2.54877975e+01
#   6.43040685e+00  1.02834637e+01  1.24334174e+01  1.41364527e+01
#   4.00317158e+00  1.27272593e+01  1.44464095e+01  8.65475703e+00
#   1.69478201e+01  9.90237441e+00  1.02659102e+01  1.38427355e+01
#   1.23467876e+01  2.84723165e+01  1.47083091e+01  2.50596643e+01
#  -7.01906801e+00  1.00316266e+01  3.09878198e+00  5.68001797e+00
#  -3.09664595e-01  1.36171013e+01  1.40272404e+01  1.30352348e+01
#   8.36882983e+00  1.13954269e+01  4.94771258e+00  1.63517776e+01
#   8.16235440e+00  9.47380721e+00  1.38160978e+01  2.91644334e+00
#   1.42675518e+01  2.10217218e+01  1.29125466e+01  1.85537462e+01
#   9.16150529e-01  8.64772332e+00  1.18967962e+01 -1.54685678e+00
#   1.39237147e+01  2.26002347e+01 -1.35727736e+01  7.68435207e-02
#   1.21703467e+01  1.52057340e+01  1.93645512e+01  1.15188850e+01
#   1.07702598e+01  1.20108203e+01  6.36520316e+00  5.11446207e+00
#   7.50824259e+00  1.03463469e+01  4.35860986e+00  4.77299472e+00
#   9.76544497e+00  1.08112926e+01  8.35486471e+00  3.73182699e+00
#   8.78920903e+00  1.87185925e+00  1.24422641e+01  6.19335632e+00
#  -7.70778699e-01  7.35568337e+00  1.04078627e+01  1.46357078e+01
#   8.18323192e+00  7.16241586e-01  1.20312557e+01  1.44810213e-01
#   1.42657633e+01  2.70046382e+00  1.47857818e+01  1.66681544e+01
#   1.11973081e+01  1.48781241e+01  4.41887481e+00  1.48336644e+00
#   5.72783468e+00  3.25732342e+00  1.70718675e+01 -3.42734758e+00
#   1.12985219e+01  8.70786134e+00  7.03724414e+00  1.54208662e+01
#   3.93809950e+00 -3.25131156e+00  6.35180434e+00  1.86850183e+00
#   5.36801520e+00  1.18492250e+01  1.15167027e-01  9.93869016e+00
#   5.41651379e-01  6.80539134e+00  2.61863328e+00  4.53505140e+00
#  -1.07950022e-03 -5.43691692e+00 -2.49659443e+00  8.76131400e+00
#  -1.78341775e+00 -9.83902929e+00 -2.26450944e+00 -8.46997134e-01
#  -1.42934623e+01 -9.16476104e+00 -5.83212913e+00 -1.71724439e+01
#  -9.34701360e+00 -8.74794039e+00 -1.57930730e+01  1.30929460e-01
#   8.80495785e+00  6.61831960e+00  4.28374823e-01  1.53282177e+00
#   6.46063699e+00 -4.75905864e+00  7.45092667e-01  6.73826264e+00
#  -6.83176146e+00  7.45107731e+00 -1.44215313e+01 -1.15542670e+01
#  -7.00664714e+00 -6.81375283e+00 -1.73195815e+01 -4.79512286e+00
#  -9.27070248e+00 -1.56267000e+01 -9.75888585e+00 -1.07705693e+01
#  -9.31684277e+00 -2.28980799e+01  2.10844902e+00 -5.72119339e+00
#   4.03740739e-01 -1.22180442e+01 -1.28983965e+01 -1.73936257e+01
#  -6.80172346e+00 -1.36609821e+01 -1.59604342e+01 -6.76479112e+00
#  -3.13765389e+00 -1.53121604e+01 -1.43445122e+01 -2.00082702e+01
#  -1.12933712e+00 -2.84549468e+01 -2.72190082e+01 -1.78676947e+01
#  -1.43512609e+01 -1.25071094e+01 -1.95825650e+01 -1.53175445e+01
#  -2.54060578e+01 -2.93544835e+01 -2.94942681e+01 -1.02215782e+01
#  -1.46752968e+01 -2.18925062e+01 -1.92665855e+01 -4.21315879e+00
#  -2.49508546e+01 -3.03757193e+01 -1.54940583e+01 -2.42142246e+01]
#
# Degree (Weighted): 3
# Estimated polynomial coefficient: [-16.77797524  20.33157168  -0.03430166  -2.23356908]
# Uncertainty in estimated coefficients: [[ 2.79741820e+00 -2.11214370e-02 -4.94029891e-01 -6.43263242e-04]
#  [-2.11214370e-02  2.39102527e+00 -8.51977430e-03 -3.44734463e-01]
#  [-4.94029891e-01 -8.51977430e-03  1.64831768e-01  3.26627502e-03]
#  [-6.43263242e-04 -3.44734463e-01  3.26627502e-03  6.08790143e-02]]
# Posterior variance factor (goodness of fit): 66.29455541456721
# Observation Residuals: [-4.45951443e+00 -3.63009535e+00 -2.58205092e+01 -2.34078105e+00
#  -5.37631684e+00 -6.42342589e-01 -4.36010473e-01 -1.32560845e+00
#  -1.40707863e+00 -1.63193407e+01  1.14597954e+00 -7.39208150e+00
#   3.25913422e+00  2.84528942e+00 -7.62700715e+00  6.95626882e+00
#  -3.42320949e+00 -8.76353767e+00  1.19320777e+00 -1.40663705e+01
#  -1.03711415e+00 -5.40327487e+00 -1.49995068e+00  2.25712978e+00
#  -1.97457813e+00 -1.39492048e+00 -6.45158181e+00  2.04384233e+01
#   2.74919437e+00  3.11552481e+00  6.74465117e+00 -2.26210952e+00
#   7.69285253e+00  4.38642531e+00 -1.45827174e+01 -1.03007521e+01
#   6.44328236e-01 -1.45464261e+01  1.99249753e-01 -1.56955028e+00
#   1.45106103e+00  7.26890785e+00  1.29657407e+00  8.48514122e-01
#   5.70201764e+00  4.85366689e-01  1.12108759e+01  6.44190967e+00
#   2.42195078e+00  2.84986853e+00  3.07044828e+01  8.75479684e+00
#   2.63888598e+01  8.07880213e+00 -6.87499177e-01 -7.71926842e-02
#  -1.97966703e+01  7.08154024e+00  5.32650852e+00 -1.18337337e+00
#  -1.56074791e+00  3.87080032e+00 -9.59002708e+00 -1.03353011e+01
#   9.83099179e+00  3.77630859e+00  1.83999054e+00 -2.12954508e+01
#   1.43210988e+01 -3.78060841e+00  6.09126625e+00  6.65431205e+00
#  -4.92957287e+00 -5.34107348e-01  2.12504060e+01  2.03777126e+00
#  -1.32382618e+00  2.41283526e+00 -1.92124050e+00  2.91921706e+00
#   1.78947180e+00  1.08947469e+01  5.55057726e-01 -9.42491110e+00
#   6.48820903e-01  5.90242163e-01  1.19986676e+00  7.01501198e+00
#   5.38053389e+00  5.46139967e+00 -6.29212944e+00  3.72575827e+00
#   6.10455960e+00 -1.67284066e+00  4.09278771e-01 -1.23887270e+01
#   7.91440190e+00  4.43523364e-01  9.54062956e+00  2.66465760e+00
#  -1.21113907e+00 -5.03774138e+00 -1.56941432e+01 -2.21016467e+01
#  -6.12632332e+00  1.02512707e+01 -1.99368343e-01 -1.73814239e+01
#   7.72705625e+00  1.03928107e+01  4.76030556e+00  4.87884021e+00
#  -1.43907100e-01 -1.36192344e+01 -6.56968623e+00 -2.53461110e+00
#  -2.97718478e+00  7.04549301e-02  3.79768514e+00 -4.22495150e+00
#   1.22753075e+01 -4.27333672e+00  2.35538363e+00  1.43821797e+00
#  -6.92148918e-01  3.38133305e-01 -3.44114910e+00  1.39034659e+00
#   2.25885165e+00 -1.50481477e-01 -5.28460041e+00 -3.52810333e+00
#   3.27107094e+00  2.53623680e+00 -1.56606210e+01  9.68568713e+00
#  -1.71591372e+01  9.86392495e+00  3.65575908e+00  1.58440252e+00
#  -2.06376739e+00  1.13035177e+00  1.33553261e+01  1.69207121e+00
#  -1.00999511e+01  1.11701198e+00  3.39555737e-01  1.45643243e+01
#  -1.07068674e+00  8.14968407e-01  3.60260019e+00 -1.78143833e+00
#   1.86009415e+01 -1.38161866e+01  7.83366735e+00  2.26299917e+00
#  -6.24815635e-01  2.94084037e+01 -2.98884101e+00 -5.33362173e+00
#   9.74326519e-02 -4.97249906e-01  6.40944869e+00 -8.38835831e-01
#  -6.07830420e-02  1.95604317e+01 -6.38595276e+00 -2.82993258e+00
#   8.17091546e+00 -3.58013239e+00 -5.43326231e+00  4.10849609e+00
#   1.18855249e+01 -2.19041334e+00 -3.01629971e+00 -4.10153832e+00
#  -5.36931993e+00  9.30456280e+00 -1.37829268e+00 -3.96335575e+00
#   1.85531489e+00  1.00016764e+01 -2.12845734e+00 -2.01712143e+01
#   2.90975821e+01 -9.84743881e+00 -6.24491677e+00 -1.85286336e-01
#  -1.84999778e+00 -2.40018661e+00  5.92504079e+00 -8.74580595e+00
#  -7.90100349e+00 -1.42875514e+00 -5.59782545e+00 -1.16067165e+00
#   1.64585379e+00 -2.26920245e+01  2.29740923e+00 -4.00470302e+00
#  -1.27540614e+01 -4.48824926e-01 -1.04936752e+00 -2.67931305e-01
#  -9.10880303e-02  1.01455932e+01 -6.11070524e+00 -8.35931225e-01
#  -8.07468534e+00 -3.91543651e-01 -1.80684978e+00 -3.53256375e+00
#  -2.35011434e+00  3.86494931e+00 -4.48319991e+00 -3.94591043e+00
#  -1.26456232e+00 -1.06301313e+01 -7.62043347e-01 -1.35614729e+00
#  -9.55038284e+00 -1.41808898e+01 -1.68191644e+01 -1.81393345e+01
#  -8.51097195e-01  8.78734526e-01  1.45519489e+00 -7.94050412e+00
#  -9.83655479e-01  2.29671943e+00 -1.22639600e+01 -3.28350834e-01
#   2.49106957e+00 -7.63147596e+00  7.76820047e+00 -6.30759097e+00
#  -9.26740704e+00  7.16082495e+00  1.15969060e+01  4.53711203e-01
#   3.90635743e+00 -2.03142196e+00 -9.16368393e+00  1.55587135e+00
#   4.13547228e+00 -3.23611091e+00  5.97114513e+00 -4.23042008e+00
#  -9.29326389e+00  9.30696354e+00  1.36442952e+01 -3.97768245e+00
#   2.04881644e+01 -2.68845647e+00  1.03117016e+00 -3.76203342e-01
#   4.18580817e+00  3.01456912e+00  1.09385527e+00 -1.94419396e+00
#  -1.67579413e+01  1.27240058e+01 -4.71641246e+00 -2.04355973e-02
#   1.56381182e+00  3.54625703e+00  4.80935764e-01 -3.99215518e+00
#  -3.28347045e+00  1.87585421e-01 -1.37697062e+00  7.02425634e-01
#  -7.15248754e-02  7.09566485e+00 -1.10810445e-01 -1.28854177e+01
#   1.39810974e+01  1.02089484e+01  2.14906762e+01 -1.31945808e+01
#  -1.05580837e+00  1.01854307e+01  5.59578808e+00  2.32683607e+00
#  -2.11806637e+01 -7.72405864e+00  3.89525838e+00  9.35831521e+00
#   5.82518633e-01  1.06556114e+01 -9.29018420e+00 -3.01124801e+00
#  -7.83927031e+00  1.46431047e-01  3.18109268e+00 -1.55813497e+00
#   2.12017785e+01  3.35885287e+00  1.40864615e+01  5.49445679e+00
#   1.68825583e+01 -6.70368958e+00  2.56568789e+00  1.41025273e+00
#   7.18349347e+00 -4.61314694e+00  2.95803752e+00  2.46559170e+00
#  -3.17084044e+00  3.04702568e+00  1.19491778e+01  4.78507226e-01
#   2.13835000e+00 -7.84195229e+00  2.86002434e+01  1.13763893e+01
#   4.62502660e+00  9.23680610e+00  5.07457696e+00  9.88614686e+00
#  -6.96321775e-02 -1.01728632e+01  3.82901609e+00  3.80827657e-01
#   2.54441038e-02  2.38953080e+00 -5.68804701e-01  1.54816731e+01
#  -3.65280364e+00  1.25278196e-01  2.20239469e+00  3.83475736e+00
#  -6.36700509e+00  2.29081941e+00  3.94595118e+00 -1.90744807e+00
#   6.32616654e+00 -7.76402505e-01 -4.67638250e-01  3.05679413e+00
#   1.51085877e+00  1.75888321e+01  3.77972820e+00  1.40884725e+01
#  -1.80303584e+01 -1.01722326e+00 -7.98506141e+00 -5.43622634e+00
#  -1.14556904e+01  2.44394011e+00  2.82961670e+00  1.81584821e+00
#  -2.86959314e+00  1.40720623e-01 -6.32049700e+00  5.07287133e+00
#  -3.12441511e+00 -1.81796538e+00  2.52220902e+00 -8.37664786e+00
#   2.97819862e+00  9.73907370e+00  1.63959761e+00  7.29351705e+00
#  -1.03283113e+01 -2.57789704e+00  6.93118308e-01 -1.27254645e+01
#   2.77333157e+00  1.14812574e+01 -2.46571370e+01 -1.09696713e+01
#   1.16494189e+00  4.24472746e+00  8.45125801e+00  6.56646874e-01
#  -3.75548061e-02  1.26082451e+00 -4.32355185e+00 -5.50960337e+00
#  -3.04765775e+00 -1.37886044e-01 -6.05042672e+00 -5.55728968e+00
#  -4.82504711e-01  6.49286924e-01 -1.71756092e+00 -6.24735581e+00
#  -1.09304138e+00 -7.90974246e+00  2.76505411e+00 -3.37569207e+00
#  -1.02278689e+01 -1.98562542e+00  1.18618549e+00  5.53753885e+00
#  -7.87525039e-01 -8.12317309e+00  3.32714034e+00 -8.42002188e+00
#   5.84422504e+00 -5.57374329e+00  6.66296996e+00  8.70082866e+00
#   3.38958613e+00  7.23415027e+00 -3.05717978e+00 -5.82057104e+00
#  -1.39976105e+00 -3.68967918e+00  1.03097362e+01 -1.00003027e+01
#   4.91907458e+00  2.52628020e+00  1.05791437e+00  9.64819969e+00
#  -1.62346506e+00 -8.59730876e+00  1.22586666e+00 -3.03285740e+00
#   6.95780103e-01  7.41068648e+00 -4.08507577e+00  5.98136905e+00
#  -3.16809534e+00  3.34789845e+00 -5.81899577e-01  1.59621154e+00
#  -2.67346666e+00 -7.83806492e+00 -4.62169004e+00  6.91711075e+00
#  -3.34186192e+00 -1.11068209e+01 -3.23672825e+00 -1.51869615e+00
#  -1.46596678e+01 -9.22047251e+00 -5.57231932e+00 -1.65920588e+01
#  -8.44097247e+00 -7.51113570e+00 -1.42203705e+01  2.04469081e+00
#   1.10649658e+01  9.22978870e+00  3.39654635e+00  4.86296376e+00
#   1.01580442e+01 -6.89064603e-01  5.19302180e+00  1.15695019e+01
#  -1.61181023e+00  1.30651691e+01 -8.40784376e+00 -5.13550150e+00
#  -1.77294943e-01  4.31721661e-01 -9.65242243e+00  3.29930997e+00
#  -7.43380106e-01 -6.66084548e+00 -3.48829843e-01 -9.10615719e-01
#   9.98731265e-01 -1.21211358e+01  1.33525395e+01  5.99584663e+00
#   1.25995602e+01  4.62411291e-01  2.72578311e-01 -3.72622133e+00
#   7.36804735e+00  1.01711881e+00 -7.68012853e-01  8.94796781e+00
#   1.31014865e+01  1.45943217e+00  2.96562995e+00 -2.15345427e+00
#   1.72763034e+01 -9.49230393e+00 -7.69315853e+00  2.22759284e+00
#   6.31972254e+00  8.74585463e+00  2.25869095e+00  7.11834169e+00
#  -2.36917645e+00 -5.71021535e+00 -5.23619460e+00  1.46567459e+01
#   1.08297497e+01  4.24576147e+00  7.51142891e+00  2.32111545e+01
#   3.12633661e+00 -1.63904448e+00  1.39087327e+01  5.86134171e+00]
#
# Degree (Weighted): 5
# Estimated polynomial coefficient: [-1.67951025e+01  2.26801815e+01 -7.07246017e-02 -3.49795817e+00
#   8.12376456e-03  1.22547782e-01]
# Uncertainty in estimated coefficients: [[ 4.66238142e+00 -4.30712037e-01 -2.51769198e+00  1.94263122e-01
#    2.44063338e-01 -1.68430339e-02]
#  [-4.30712037e-01  5.81464399e+00  3.34199470e-01 -2.22552007e+00
#   -3.52798101e-02  1.83409202e-01]
#  [-2.51769198e+00  3.34199470e-01  2.26102474e+00 -1.54314750e-01
#   -2.51063359e-01  1.31574963e-02]
#  [ 1.94263122e-01 -2.22552007e+00 -1.54314750e-01  1.07668427e+00
#    1.57880815e-02 -9.85356800e-02]
#  [ 2.44063338e-01 -3.52798101e-02 -2.51063359e-01  1.57880815e-02
#    2.99722930e-02 -1.27952489e-03]
#  [-1.68430339e-02  1.83409202e-01  1.31574963e-02 -9.85356800e-02
#   -1.27952489e-03  9.53438313e-03]]
# Posterior variance factor (goodness of fit): 63.28984491321929
# Observation Residuals: [ 8.02175575e-01  1.33571722e+00 -2.11425728e+01  2.05715372e+00
#  -1.25063483e+00  3.21871103e+00  3.16791580e+00  2.02856929e+00
#   1.70460830e+00 -1.34430068e+01  3.79397930e+00 -4.96551469e+00
#   5.47105265e+00  4.84922850e+00 -5.82449279e+00  8.56379977e+00
#  -2.00433287e+00 -7.52709746e+00  2.25331945e+00 -1.31765885e+01
#  -3.11770758e-01 -4.83658601e+00 -1.08623798e+00  2.52343995e+00
#  -1.85020052e+00 -1.40710808e+00 -6.59506883e+00  2.01688021e+01
#   2.35850474e+00  2.60873403e+00  6.12662909e+00 -2.98658948e+00
#   6.86659272e+00  3.46296927e+00 -1.55988795e+01 -1.14052222e+01
#  -5.44143504e-01 -1.58146834e+01 -1.14466632e+00 -2.98508689e+00
#  -3.21452489e-02  5.72189628e+00 -3.10463886e-01 -8.14855846e-01
#   3.98592647e+00 -1.27991748e+00  9.39984526e+00  4.58849845e+00
#   5.29445026e-01  9.21475483e-01  2.87433319e+01  6.76394029e+00
#   2.43712741e+01  6.03738833e+00 -2.74991399e+00 -2.15785481e+00
#  -2.18928984e+01  4.97235592e+00  3.20690720e+00 -3.31092217e+00
#  -3.69384351e+00  1.73449065e+00 -1.17272851e+01 -1.24713081e+01
#   7.69837010e+00  1.64914187e+00 -2.79715106e-01 -2.34057520e+01
#   1.22220835e+01 -5.86651745e+00  4.02022370e+00  4.59983679e+00
#  -6.96583855e+00 -2.55057892e+00  1.92552562e+01  6.54147660e-02
#  -3.27197307e+00  4.90259812e-01 -3.81693635e+00  1.05165611e+00
#  -4.87510169e-02  9.08701414e+00 -1.22108348e+00 -1.11684090e+01
#  -1.06103098e+00 -1.08500905e+00 -4.39876577e-01  5.41163709e+00
#   3.81434211e+00  3.93316054e+00 -7.78169078e+00  2.27555620e+00
#   4.69435538e+00 -3.04245064e+00 -9.19182012e-01 -1.36755243e+01
#   6.66974214e+00 -7.58563876e-01  8.38151117e+00  1.54886651e+00
#  -2.28328161e+00 -6.06595057e+00 -1.66781701e+01 -2.30412773e+01
#  -7.02137833e+00  9.40093702e+00 -1.00486801e+00 -1.81420093e+01
#   7.01143347e+00  9.72216802e+00  4.13462986e+00  4.29808869e+00
#  -6.79806408e-01 -1.41103820e+01 -7.01621041e+00 -2.93666745e+00
#  -3.33495549e+00 -2.43238310e-01  3.52783583e+00 -4.45121518e+00
#   1.20923470e+01 -4.41330007e+00  2.25808850e+00  1.38323974e+00
#  -7.05183339e-01  3.66648426e-01 -3.37149931e+00  1.50069613e+00
#   2.40944657e+00  3.98855481e-02 -5.05495289e+00 -3.25968469e+00
#   3.57773407e+00  2.88060114e+00 -1.52791149e+01  1.01037599e+01
#  -1.67050878e+01  1.03533463e+01  4.17993368e+00  2.14269821e+00
#  -1.47199577e+00  1.75494168e+00  1.40120647e+01  2.38027739e+00
#  -9.38096942e+00  1.86606668e+00  1.11797088e+00  1.53713778e+01
#  -2.35725940e-01  1.67709681e+00  4.49114842e+00 -8.67225689e-01
#   1.95400559e+01 -1.28529396e+01  8.82027122e+00  3.27217851e+00
#   4.06152360e-01  3.04603685e+01 -1.91667560e+00 -4.24205619e+00
#   1.20759424e+00  6.30700358e-01  7.55437741e+00  3.22258686e-01
#   1.11566256e+00  2.07514120e+01 -5.18125530e+00 -1.61233648e+00
#   9.40059125e+00 -2.33919596e+00 -4.18188404e+00  5.36949807e+00
#   1.31553335e+01 -9.12614010e-01 -1.73132363e+00 -2.81019746e+00
#  -4.07242385e+00  1.06062073e+01 -7.27034300e-02 -2.65462202e+00
#   3.16639661e+00  1.13143137e+01 -8.15052467e-01 -1.88578252e+01
#   3.04101772e+01 -8.53641059e+00 -4.93622279e+00  1.12031202e+00
#  -5.48250217e-01 -1.10303850e+00  7.21684756e+00 -7.46007533e+00
#  -6.62207651e+00 -1.57351696e-01 -4.33465756e+00  9.35567780e-02
#   2.89044722e+00 -2.14577529e+01  3.52068081e+00 -2.79310032e+00
#  -1.15547872e+01  7.37470791e-01  1.23309472e-01  8.90496745e-01
#   1.05247111e+00  1.12736739e+01 -4.99870188e+00  2.59406797e-01
#  -6.99658964e+00  6.68744007e-01 -7.64924457e-01 -2.50954345e+00
#  -1.34652993e+00  4.84857891e+00 -3.52003190e+00 -3.00369846e+00
#  -3.43788395e-01 -9.73126478e+00  1.14459110e-01 -5.02452562e-01
#  -8.71992647e+00 -1.33740893e+01 -1.60364238e+01 -1.73810443e+01
#  -1.17634687e-01  1.58700605e+00  2.13792587e+00 -7.28364932e+00
#  -3.52998463e-01  2.90087118e+00 -1.16866068e+01  2.21924896e-01
#   3.01400326e+00 -7.13613437e+00  8.23571442e+00 -5.86812555e+00
#  -8.85619633e+00  7.54358949e+00  1.19510478e+01  7.79068403e-01
#   4.20278324e+00 -1.76405942e+00 -8.92550154e+00  1.76477173e+00
#   4.31500389e+00 -3.08601977e+00  6.09173922e+00 -4.13936450e+00
#  -9.23177314e+00  9.33887830e+00  1.36466379e+01 -4.00489260e+00
#   2.04314356e+01 -2.77465451e+00  9.15567353e-01 -5.21131327e-01
#   4.01164964e+00  2.81128972e+00  8.61579673e-01 -2.20532613e+00
#  -1.70477755e+01  1.24056390e+01 -5.06312773e+00 -3.95300345e-01
#   1.16101125e+00  3.11574890e+00  2.29628884e-02 -4.47733552e+00
#  -3.79558658e+00 -3.51180521e-01 -1.94208619e+00  1.11274734e-01
#  -6.88382788e-01  6.45344215e+00 -7.78041903e-01 -1.35772882e+01
#   1.32649711e+01  9.46896312e+00  2.07272419e+01 -1.39810409e+01
#  -1.86485797e+00  9.35424079e+00  4.74291972e+00  1.45276383e+00
#  -2.20754528e+01 -8.63906543e+00  2.96054535e+00  8.40441926e+00
#  -3.90025104e-01  9.66496657e+00 -1.02983720e+01 -4.03640937e+00
#  -8.88082489e+00 -9.10925520e-01  2.10853597e+00 -2.64527955e+00
#   2.01006685e+01  2.24440997e+00  1.29593280e+01  4.35528436e+00
#   1.57320081e+01 -7.86494733e+00  1.39440161e+00  2.29625556e-01
#   5.99422138e+00 -5.81035987e+00  1.75359566e+00  1.25464038e+00
#  -4.38757443e+00  1.82524283e+00  1.07230866e+01 -7.51145160e-01
#   9.05889589e-01 -9.07646161e+00  2.73644499e+01  1.01400816e+01
#   3.38897977e+00  8.00179980e+00  3.84139525e+00  8.65557787e+00
#  -1.29679663e+00 -1.13958279e+01  2.61104949e+00 -8.31339832e-01
#  -1.18012087e+00  1.19137379e+00 -1.75874661e+00  1.43007547e+01
#  -4.82388899e+00 -1.03516413e+00  1.05340566e+00  2.69803175e+00
#  -7.49065767e+00  1.18104854e+00  2.85086943e+00 -2.98703497e+00
#   5.26287809e+00 -1.82259135e+00 -1.49592926e+00  2.04719588e+00
#   5.20744487e-01  1.66189889e+01  2.83093845e+00  1.31615137e+01
#  -1.89347142e+01 -1.89820984e+00 -8.84191899e+00 -6.26820185e+00
#  -1.22620381e+01  1.66395851e+00  2.07673113e+00  1.09078003e+00
#  -3.56613166e+00 -5.26585513e-01 -6.95787809e+00  4.46609739e+00
#  -3.69991078e+00 -2.36152323e+00  2.01123654e+00 -8.85439995e+00
#   2.53428889e+00  9.32961475e+00  1.26518378e+00  6.95472808e+00
#  -1.06309108e+01 -2.84375809e+00  4.64528471e-01 -1.29162672e+01
#   2.62081492e+00  1.13675076e+01 -2.47316574e+01 -1.10045189e+01
#   1.17019125e+00  4.29047765e+00  8.53789230e+00  7.84527268e-01
#   1.31911871e-01  1.47219523e+00 -4.06998236e+00 -5.21356397e+00
#  -2.70890153e+00  2.43809078e-01 -5.62559604e+00 -5.08915285e+00
#   2.90821894e-02  1.20444052e+00 -1.11875195e+00 -5.60483133e+00
#  -4.06770487e-01 -7.17972410e+00  3.53879050e+00 -2.55829825e+00
#  -9.36691012e+00 -1.08122648e+00  2.13386651e+00  6.52831008e+00
#   2.46110036e-01 -7.04693571e+00  4.44568262e+00 -7.25950867e+00
#   7.04633796e+00 -4.33043983e+00  7.94701612e+00  1.00251303e+01
#   4.75361598e+00  8.63734022e+00 -1.61543934e+00 -4.34093201e+00
#   1.17081713e-01 -2.13637130e+00  1.18987261e+01 -8.37645906e+00
#   6.57689776e+00  4.21716188e+00  2.78088607e+00  1.14022447e+01
#   1.60587457e-01 -6.78436428e+00  3.06653698e+00 -1.16567875e+00
#   2.58819742e+00  9.32701986e+00 -2.14620267e+00  7.94135096e+00
#  -1.18849089e+00  5.34558302e+00  1.43226571e+00  3.62520030e+00
#  -6.31370278e-01 -5.78463624e+00 -2.55876469e+00  8.98763599e+00
#  -1.26569554e+00 -9.02703497e+00 -1.15540806e+00  5.62008451e-01
#  -1.25817940e+01 -7.14771110e+00 -3.50701897e+00 -1.45366362e+01
#  -6.39791331e+00 -5.48299541e+00 -1.22097752e+01  4.03504339e+00
#   1.30323055e+01  1.11712718e+01  5.30925498e+00  6.74390478e+00
#   1.20041484e+01  1.11905628e+00  6.95993509e+00  1.32919044e+01
#   6.26982055e-02  1.46883195e+01 -6.83959693e+00 -3.62578672e+00
#   1.27017570e+00  1.81315146e+00 -8.34091576e+00  4.53692463e+00
#   4.16286161e-01 -5.58327252e+00  6.42415375e-01 -1.00231522e-02
#   1.80425478e+00 -1.14151902e+01  1.39543048e+01  6.48873471e+00
#   1.29787787e+01  7.23071317e-01  4.09693400e-01 -3.71773621e+00
#   7.24271786e+00  7.52689428e-01 -1.17692910e+00  8.38907502e+00
#   1.23870237e+01  5.83701027e-01  1.92282628e+00 -3.36924162e+00
#   1.58815132e+01 -1.10722253e+01 -9.46444943e+00  2.58582657e-01
#   4.14653103e+00  6.36190630e+00 -3.42704210e-01  4.29269404e+00
#  -5.42599898e+00 -9.00525301e+00 -8.77660659e+00  1.08636802e+01
#   6.77662999e+00 -7.49352244e-02  2.91550895e+00  1.83322403e+01
#  -2.04346841e+00 -7.10776394e+00  8.13294713e+00 -2.29790720e-01]

# %%
# step 14
# Compare the results of a posterier variance factor and norm from unweighted LSE and weighted LSE, what phenomena do you observe? Explain this phenomena.
# (2 marks)
for degree in [1, 3, 5]:
    print(f"\nComparison for Degree {degree}:")
    print(f"Unweighted APV: {results[degree]['posterior_variance']}")
    print(f"Weighted APV: {weighted_results[degree]['posterior_variance']}")
    print(f"Unweighted Residual Norm: {np.linalg.norm(results[degree]['residuals'] - l_true)}")
    print(f"Weighted Residual Norm: {np.linalg.norm(weighted_results[degree]['residuals'] - l_true)}")

print("1. The posterior variance factors for weighted LSE are smaller compared to the unweighted LSE.")
print("   This indicates that weighted LSE improves the goodness of fit by prioritizing more reliable observations.")
print()
print("2. The norm between the predicted and true observations is also smaller for weighted LSE.")
print("   This shows that the weighted LSE provides a better approximation of the true function.")
print()
print("3. Explanation: Weighted LSE accounts for the varying accuracy of data points by assigning more importance to observations with lower variance.")
print("   This results in a more accurate and robust fit compared to unweighted LSE, which treats all observations equally.")
# Out:
# Comparison for Degree 1:
# Unweighted APV: 162.0916381699047
# Weighted APV: 162.68043950201857
# Unweighted Residual Norm: 505.7617589932044
# Weighted Residual Norm: 514.7389833956422
#
# Comparison for Degree 3:
# Unweighted APV: 65.60321960866828
# Weighted APV: 66.29455541456721
# Unweighted Residual Norm: 553.8932217946349
# Weighted Residual Norm: 561.0187862158944
#
# Comparison for Degree 5:
# Unweighted APV: 62.99324449462198
# Weighted APV: 63.28984491321929
# Unweighted Residual Norm: 554.9430616277232
# Weighted Residual Norm: 557.465208217961
# 1. The posterior variance factors for weighted LSE are smaller compared to the unweighted LSE.
#    This indicates that weighted LSE improves the goodness of fit by prioritizing more reliable observations.
#
# 2. The norm between the predicted and true observations is also smaller for weighted LSE.
#    This shows that the weighted LSE provides a better approximation of the true function.
#
# 3. Explanation: Weighted LSE accounts for the varying accuracy of data points by assigning more importance to observations with lower variance.
#    This results in a more accurate and robust fit compared to unweighted LSE, which treats all observations equally.

# %% [markdown]
# # **Non-linear LSE**
# ### (35 Marks)

# %% [markdown]
# ### **SinglePointPositioning**

# %% [markdown]
# ### **Observations:** Pseudorange [m]

# %% [markdown]
# ![code.jpg](data:image/jpeg;base64,...)
#
# <font size="1.5">Image source: *ICA Course on Toponymy. https://unstats.un.org/unsd/geoinfo/ungegn/docs/_data_icacourses/_HtmlModules/_Selfstudy/S06/S06_05b.html.*</font>

# %% [markdown]
# **Pseudorange** is the *pseudo* distance between a satellite and a satellite signal receiver on the ground. In simple words, it contains the geometric range between the satellite and the receiver, with additional associated errors.

# %% [markdown]
# The simplified version of the Pseudorange measurement model is:
# $$P=\rho-cdT+ϵ_{sum}$$ and
# $$\rho=\sqrt{(x_s - x_r)^2 + (y_s - y_r)^2 + (z_s - z_r)^2}$$
# where
# $$\rho=geometric\ range$$
# $${x_s, y_s, z_s, x_r,y_r,z_r} = 3D\ coordinates\ of\ satellite\ and\ receiver$$
# $$cdT = receiver\ clock\ offset$$
# $$ϵ_{sum}=general\ errors\ term\ (ϵ_{sum}=\Delta \rho + \Delta_{\text{ion}} + \Delta_{\text{trop}} + \epsilon_P + cdt)$$
#
# \\
# Note: the 3D **positions of satellites** are given in this assignment.

# %% [markdown]
# ### **Unknown States:** Position of receiver & receiver clock offset

# %% [markdown]
# We use the psuedorange measurements to estimate the receiver's **3-dimensional position** and the **receiver clock offset:** $$X={x_r,y_r,z_r,cdT}$$.
#
# These will be our states of interest, and we are going to estimate them in the following Least Square Estimation.

# %%
# step 1
# Load the psuedorange measurements and satellites' positions files, store them in the format of numpy array
# (hint: use pandas library to parse excel files into dataframe first, then convert them to numpy arrays)
# (1 marks)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.linalg import inv

satellite_position = pd.read_excel('drive/MyDrive/engg680_2024_fall/Lab_Assignment2/satellite_position.xlsx')
pseudoranges = pd.read_excel('drive/MyDrive/engg680_2024_fall/Lab_Assignment2/pseudoranges.xlsx')

sat_pos = satellite_position[['x', 'y', 'z']].to_numpy()
pseudo = pseudoranges['P'].to_numpy()

# %%
# step 2
# define the number of measurements n and the number of states m
# (2 mark)
n = len(pseudo)
m = 4

# %%
# step 3
# Given that the variance of observation is 1 (m^2), define the weight matrix P
# (1 marks)
P = np.eye(n)

# %%
# step 4
# set the initial states as zeros:
# (1 mark)
x_0 = np.zeros(4)

# %%
# step 5
# GroundTruth coordiantes of the receiver
GroundTruth=np.array([-1633489.37967725,	-3651627.18250363,	4952481.61954918])

# %%
# step 6
# initialize the corrections array as ones, iteration loop counter i as zero and related arrays
# (2 mark)
delta = np.ones(m)
threshold = 0.001
max_iterations = 100
i = 0

arr_w = []
arr_delta=[]
arr_err_pos = []
arr_i = []
x_hat = x_0

# %%
# step 7
# define a function called euclidean_norm, which computes the geometric distances between satellites and receiver
# the input of the function should be two arrays: receiver_pos and satellite_pos
# the function should return an array of distance between satellites and receiver
# you can either use the numpy function or code the math manually
# (1 marks)
def euclidean_norm(receiver_pos, satellite_pos):
  return np.linalg.norm(receiver_pos - satellite_pos, axis=1)

# %%
# step 8
# define a function named design_matrix which computes the design matrix A of this LSE problem
# the input of this funciton should be: estimated states array, satellites positions array and geometric distance array
# the function should return an two-dimensional array which represents the design matrix A
# (2 marks)
def design_matrix(r_pos, s_pos):
  n = s_pos.shape[0]
  A = np.zeros((n, 4))
  for j in range(n):
    diff = s_pos[j] - r_pos[:3]
    norm_val = np.linalg.norm(diff)
    A[j,:3] = -diff / norm_val
    A[j, 3] = -1
  return A

# %%
from re import A
# step 9
# start the iteration for the LSE (11 marks in total)

# define the convergence criteria for the 'while' loop
# the convergence criteria is that the corrections delta are less than 0.001 (i.e., <0.1 m), for receiver's position x,y,z part
# (1 marks)

max_iterations = 100
while np.linalg.norm(delta) > 0.001 and i < max_iterations:

       # compute the geometri distance between Satellites and receiver, using the euclidean_norm function we just defined
       # (1 marks)
       rho = euclidean_norm(x_hat[:3], sat_pos)

       # compute the design matrix A
       # (1 marks)
       A = design_matrix(x_hat, sat_pos)

       # compute the misclosure array w
       # (1 marks)
       w = pseudo - (rho + x_hat[3])

       # compute the corrections delta
       # (1 marks)
       from numpy.linalg import pinv, cond
       if cond(A.T @ P @ A) > 1e10:
         delta = pinv(A.T @ P @ A) @ (A.T @ P @ w)
       else:
        delta = inv(A.T @ P @ A) @ (A.T @ P @ w)



       # update the states
       # (1 marks)
       x_hat = x_hat + delta


       # compute the position error from using the updated states against groundtruth
       # (1 marks)
       err_pos = np.linalg.norm(x_hat[:3] - GroundTruth)


       # update the counter i, (i.e., increament of 1 for each iteration)
       # (1 mark)
       i += 1

       # store the misclosure, delta, position error and counter from each iteration into arrays, we will use them for plotting
       # (1 marks)
       arr_w.append(np.log(np.linalg.norm(w)))
       arr_delta.append(np.log(np.linalg.norm(delta)))
       arr_err_pos.append(np.log(err_pos))
       arr_i.append(i)






# After convergence, compute the A Posteriori Variance of Unit Weight
# (1 marks)
apv = (w.T @ P @ w) / (n-m)

# compute the Covariance matrix of estimated states
# (1 marks)
A = design_matrix(x_hat, sat_pos)
try:
    C_x_hat = inv(A.T @ P @ A) * apv
except np.linalg.LinAlgError:
    C_x_hat = pinv(A.T @ P @ A) * apv

# %%
# step 10
"""
Print:
      {estimated states,
       corrections array,
       estimated measurements residuals,
       A posteriori Variance of Unit Weight,
       Covariance matrix of estimated states,
       number of iterations,
       3-D position errors},

after the LSE convergence to the console.
"""
# (7 marks)
print("\n=== Final Results ===")
print("Estimated States:")
print(x_hat)
print("\nCorrections Array:")
print(delta)
print("\nEstimated Measurements Residuals:")
print(w)
print("\nA Posteriori Variance of Unit Weight:")
print(apv)
print("\nCovariance Matrix of Estimated States:")
print(C_x_hat)
print("\nNumber of Iterations:")
print(i)
print("\n3-D Position Errors:")
print(arr_err_pos)
# Out:
# === Final Results ===
# Estimated States:
# [-2.79945070e+23 -2.79954452e+24 -2.51970991e+24 -3.95672231e+24]
#
# Corrections Array:
# [-6.66535870e+21 -6.66558208e+22 -5.99930922e+22 -8.99255056e+22]
#
# Estimated Measurements Residuals:
# [1.79851011e+23 1.79851011e+23 1.79851011e+23 1.79851011e+23
#  1.79851011e+23 1.79851011e+23 1.79851011e+23 1.79851011e+23
#  1.79851011e+23 1.79851011e+23 1.79851011e+23]
#
# A Posteriori Variance of Unit Weight:
# 5.083003550906103e+46
#
# Covariance Matrix of Estimated States:
# [[6.34671523e+42 6.34692793e+43 5.71250684e+43 8.56265359e+43]
#  [6.34692793e+43 6.34714063e+44 5.71269829e+44 8.56294055e+44]
#  [5.71250684e+43 5.71269829e+44 5.14167301e+44 7.70701307e+44]
#  [8.56265359e+43 8.56294055e+44 7.70701307e+44 1.15522808e+45]]
#
# Number of Iterations:
# 100
#
# 3-D Position Errors:
# [13.968666725656771, 10.402524015681294, 3.478974383157849, 1.6922395799111372, 1.6922364581918021, 1.6922364574023367, 1.692236455823406, 1.6922364226241915, 1.6922363918088403, 1.692236534141149, 1.69223609476022, 1.6922363918088403, 1.692236315525217, 1.6922386423771223, 1.6922415220365021, 1.6922379898085942, 1.6922537672215134, 1.6922553523171466, 1.6922602343613264, 1.6922602343613264, 1.6919687260214873, 1.6916254052755793, 1.6942919298684964, 1.6952502515248435, 1.6972597071700408, 1.6926162609908106, 1.6653525351852225, 1.7043576395740692, 1.6110855899485605, 1.6256329433603873, 1.2427188727175968, 2.149328112307245, 2.5238809456447413, 2.543964933329132, 1.7063221910354986, 3.0267286588441102, 4.123807651579774, 5.360431647918551, 6.1646161900224685, 6.883742040623269, 6.012798270457867, 8.32797962639375, 7.579015679900098, 9.04566650866754, 9.049047587499429, 10.975502332022627, 11.251654899869393, 11.28519727309653, 11.28519727309653, 13.93510556934739, 13.955798997727447, 15.492995056763588, 16.302343861622077, 13.94860361368526, 15.979767239916672, 17.03430064866722, 18.613708519636603, 27.555172614341842, 52.85326928185818, 53.546416103967196, 53.95188109259169, 54.23956310530163, 54.46270662077073, 54.64502815366795, 54.79917881642611, 54.932710196248806, 55.050493221948216, 55.15585372964046, 55.251163902927495, 55.33817527448605, 55.418217977564055, 55.49232594577875, 55.561318813851884, 55.62585733200236, 55.68648195118313, 55.74364036268026, 55.79770758185433, 55.8490008743553, 55.89779103681782, 55.94431105090098, 55.98876281205501, 56.03132242517507, 56.072144418500486, 56.11136513055084, 56.149105457512455, 56.18547310073505, 56.22056441966343, 56.25446597051509, 56.28725579256722, 56.31900449015912, 56.34977614814699, 56.37962911065772, 56.40861664692853, 56.43678752332625, 56.464186496976154, 56.490854743548425, 56.51683022946795, 56.542148036992685, 56.566840649145924, 56.59093820030866]

# %%
# step 11
# Comment on the computed A Posteriori Variance of Unit Weight value and the Covariance matrix of estimated states
# (2 marks)
#The APV value and covariance matrix suggest that the estimation process is reliable and observation fit the model well.

# %%
# step 12
# Using the imported matplotlib, plot the following (3 marks in total). Make sure to include proper axes information, legend, grid lines and title.
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
# 1. Plot log of the misclosure w against the LSQ iteration number i
# (1 marks)
plt.subplot(3, 1, 1)
plt.plot(arr_i, arr_w, label='Log(Misclosure w)', color='b')
plt.xlabel('Iteration Number (i)')
plt.ylabel('Log(Misclosure)')
plt.title('Log of Misclosure vs Iteration Number')
plt.grid(True)
plt.legend()

# 2. Plot log of the corrections delta against the LSQ iteration number i
# (1 marks)
plt.subplot(3, 1, 2)
plt.plot(arr_i, arr_delta, label='Log(Corrections Delta)', color='r')
plt.xlabel('Iteration Number (i)')
plt.ylabel('Log(Corrections)')
plt.title('Log of Corrections Delta vs Iteration Number')
plt.grid(True)
plt.legend()

# 3. Plot log of the 3D position errors against the LSQ iteration number i
# (1 marks)
plt.subplot(3, 1, 3)
plt.plot(arr_i, arr_err_pos, label='Log(3D Position Error)', color='g')
plt.xlabel('Iteration Number (i)')
plt.ylabel('Log(Position Error)')
plt.title('Log of 3D Position Error vs Iteration Number')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
# step 13
# Describe the phenomena or pattern you recognize for each plot, and explain such phenomena
# (2 marks)
#Log of Misclosure vs Iteration Number : Linear Increase
#Log of Corrections Delta vs Iteration Number : Decrease with each iteration
#Log of 3D Position Error vs Iteration Number : Fluctuates

# %%
# this is just for fun (no marks allocated)
# now you can estimate the receiver's position in Earth-center-earth-fixed (ECEF)
# you can use this tool: https://www.oc.nps.edu/oc2902w/coord/llhxyz.htm to convert it to latitude, longitude and height
# and find where is it on google earth!
